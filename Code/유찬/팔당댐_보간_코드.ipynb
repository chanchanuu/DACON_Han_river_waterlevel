# %%
df1= df[['날짜','현재수위']]
df1['날짜'] = df1['날짜'].apply(lambda x: datetime.strptime(x,"%Y-%m-%d %H:%M"))
df1 = df1.set_index('날짜')
col_현재수위 = df1.interpolate(method = 'time')
col_현재수위.to_csv('/content/drive/MyDrive/팔당댐/col_현재수위.csv')

df2= df[['날짜','유입량']]
df2['날짜'] = df2['날짜'].apply(lambda x: datetime.strptime(x,"%Y-%m-%d %H:%M"))
df2 = df2.set_index('날짜')
col_유입량 = df2.interpolate(method = 'time')
col_유입량.to_csv('/content/drive/MyDrive/팔당댐/col_유입량.csv')


df3= df[['날짜','저수량']]
df3['날짜'] = df3['날짜'].apply(lambda x: datetime.strptime(x,"%Y-%m-%d %H:%M"))
df3 = df3.set_index('날짜')
col_저수량 = df3.interpolate(method = 'time')
col_저수량.to_csv('/content/drive/MyDrive/팔당댐/col_저수량.csv')


df4= df[['날짜','공용량']]
df4['날짜'] = df4['날짜'].apply(lambda x: datetime.strptime(x,"%Y-%m-%d %H:%M"))
df4 = df4.set_index('날짜')
col_공용량 = df4.interpolate(method = 'time')
col_공용량.to_csv('/content/drive/MyDrive/팔당댐/col_공용량.csv')


df5= df[['날짜','방류량']]
df5['날짜'] = df5['날짜'].apply(lambda x: datetime.strptime(x,"%Y-%m-%d %H:%M"))
df5 = df5.set_index('날짜')
col_방류량 = df5.interpolate(method = 'time')
col_방류량.to_csv('/content/drive/MyDrive/팔당댐/col_방류량.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
