# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings(action='ignore')

import time
from glob import glob
from tqdm import tqdm

import tensorflow as tf
import tensorflow.keras as keras
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras import backend as K
from keras.utils import plot_model

from keras.layers import Activation, Dense, LSTM, GRU, Bidirectional, AveragePooling1D, GlobalAveragePooling1D, Dropout, Flatten, BatchNormalization, TimeDistributed, Input, Reshape, RepeatVector, Concatenate, GlobalMaxPooling1D 
from keras.layers.convolutional import Conv1D, MaxPooling1D, AveragePooling1D


#GPU 자원이 부족
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
raw_data = pd.read_csv('C:/Users/sjkan/Desktop/연세/YBIGTA/22 여름방학/신입기수프로젝트/rawdata.csv')
raw_data = raw_data[:-6912]

# %%
# 날짜를 index로 바꾸고 dtype을 datetime으로 바꾸기
raw_data.set_index(keys = ['날짜'], inplace = True)
raw_data.index = pd.to_datetime(raw_data.index, format = '%Y-%m-%d %H:%M')

# %%
raw_data.isnull().sum()
# Out:
# 현재수위          707
# 유입량           707
# 저수량           707
# 공용량           707
# 방류량           707
# 강화대교_조위      4923
# 청담대교_유량     15164
# 잠수교_유량     189937
# 한강대교_유량      1279
# 행주대교_유량        59
# 대곡교_강수량         0
# 진관교_강수량         0
# 송정동_강수량         0
# 청담대교_수위        59
# 잠수교_수위         59
# 한강대교_수위        59
# 행주대교_수위        59
# dtype: int64

# %%
raw_data
# Out:
#                        현재수위     유입량     저수량    공용량     방류량  강화대교_조위  청담대교_유량  \
# 날짜
# 2012-05-01 00:00:00  24.800  555.00  219.07  24.93  555.00    445.0   469.05
# 2012-05-01 00:10:00  24.794  464.60  218.86  25.15  562.90    449.0   498.00
# 2012-05-01 00:20:00  24.789  478.10  218.69  25.31  576.40    451.0   490.68
# 2012-05-01 00:30:00  24.789  464.80  218.69  25.31  563.10    452.0   476.21
# 2012-05-01 00:40:00  24.789  478.10  218.69  25.31  576.40    450.0   476.21
# ...                     ...     ...     ...    ...     ...      ...      ...
# 2022-05-31 23:10:00  25.180  140.94  217.99  26.01  140.94    220.0   285.72
# 2022-05-31 23:20:00  25.180  141.07  217.99  26.01  141.07    208.0   274.78
# 2022-05-31 23:30:00  25.180  141.01  217.99  26.01  141.01    196.0   269.40
# 2022-05-31 23:40:00  25.190  755.75  218.36  25.64  140.75    184.0   264.07
# 2022-05-31 23:50:00  25.190  140.56  218.36  25.64  140.56    173.0   269.40
#
#                      잠수교_유량  한강대교_유량  행주대교_유량  대곡교_강수량  진관교_강수량  송정동_강수량  \
# 날짜
# 2012-05-01 00:00:00     0.0   729.80   540.18      0.0      0.0      0.0
# 2012-05-01 00:10:00     0.0   731.48   540.18      0.0      0.0      0.0
# 2012-05-01 00:20:00     0.0   726.42   540.18      0.0      0.0      0.0
# 2012-05-01 00:30:00     0.0   726.42   552.17      0.0      0.0      0.0
# 2012-05-01 00:40:00     0.0   707.17   564.29      0.0      0.0      0.0
# ...                     ...      ...      ...      ...      ...      ...
# 2022-05-31 23:10:00     NaN   575.57   493.58      0.0      0.0      0.0
# 2022-05-31 23:20:00     NaN   501.04   505.03      0.0      0.0      0.0
# 2022-05-31 23:30:00     NaN   425.89   505.03      0.0      0.0      0.0
# 2022-05-31 23:40:00     NaN   198.19   493.58      0.0      0.0      0.0
# 2022-05-31 23:50:00     NaN    70.09   482.26      0.0      0.0      0.0
#
#                      청담대교_수위  잠수교_수위  한강대교_수위  행주대교_수위
# 날짜
# 2012-05-01 00:00:00    310.7   300.2    290.0    275.3
# 2012-05-01 00:10:00    314.7   300.2    290.0    275.3
# 2012-05-01 00:20:00    313.7   301.2    290.0    275.3
# 2012-05-01 00:30:00    311.7   301.2    290.0    276.3
# 2012-05-01 00:40:00    311.7   301.2    291.0    277.3
# ...                      ...     ...      ...      ...
# 2022-05-31 23:10:00    281.7   281.2    278.0    271.3
# 2022-05-31 23:20:00    279.7   279.2    278.0    272.3
# 2022-05-31 23:30:00    278.7   277.2    277.0    272.3
# 2022-05-31 23:40:00    277.7   276.2    276.0    271.3
# 2022-05-31 23:50:00    278.7   276.2    275.0    270.3
#
# [269424 rows x 17 columns]

# %%
from glob import glob

xdata = pd.read_csv("C:/Users/sjkan//Desktop/행주대교_유량 수위x4 완성.csv", encoding = 'cp949')
xdata
# Out:
#         행주대교_유량  청담대교_수위  잠수교_수위  한강대교_수위  행주대교_수위
# 0        540.18    310.7   300.2    290.0    275.3
# 1        540.18    314.7   300.2    290.0    275.3
# 2        540.18    313.7   301.2    290.0    275.3
# 3        552.17    311.7   301.2    290.0    276.3
# 4        564.29    311.7   301.2    291.0    277.3
# ...         ...      ...     ...      ...      ...
# 276331   974.40    288.0   295.0    299.0    306.0
# 276332  1006.88    287.0   303.0    304.0    308.0
# 276333  1039.90    299.0   307.0    309.0    310.0
# 276334  1073.46    309.0   311.0    314.0    312.0
# 276335  1090.45    326.0   314.0    317.0    313.0
#
# [276336 rows x 5 columns]

# %%
xdata = xdata[:-6912]
xdata
# Out:
#         행주대교_유량  청담대교_수위  잠수교_수위  한강대교_수위  행주대교_수위
# 0        540.18    310.7   300.2    290.0    275.3
# 1        540.18    314.7   300.2    290.0    275.3
# 2        540.18    313.7   301.2    290.0    275.3
# 3        552.17    311.7   301.2    290.0    276.3
# 4        564.29    311.7   301.2    291.0    277.3
# ...         ...      ...     ...      ...      ...
# 269419   493.58    281.7   281.2    278.0    271.3
# 269420   505.03    279.7   279.2    278.0    272.3
# 269421   505.03    278.7   277.2    277.0    272.3
# 269422   493.58    277.7   276.2    276.0    271.3
# 269423   482.26    278.7   276.2    275.0    270.3
#
# [269424 rows x 5 columns]

# %%
# 정규화
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

input_x_regular = xdata.copy()

for i in range(len(xdata.columns)):
    scaler = MinMaxScaler()                       #StandardScaler() , MinMaxScaler() , RobustScaler()
    a=np.array(input_x_regular.iloc[:,i])
    tmp_x = scaler.fit_transform(a.reshape(-1,1))
    input_x_regular.iloc[:,i] = tmp_x

# %% [markdown]
# # 원하는 칼럼명 입력하기

# %%
#ydata = raw_data[['현재수위','유입량','저수량','공용량','방류량','강화대교_조위','청담대교_유량','잠수교_유량','한강대교_유량']]
ydata = raw_data[['청담대교_유량']]

# %% [markdown]
# # 원하는 칼럼명 입력하기

# %%
ydata = ydata.reset_index()
ydata = ydata.청담대교_유량
ydata = pd.DataFrame(ydata)
ydata
# Out:
#         청담대교_유량
# 0        469.05
# 1        498.00
# 2        490.68
# 3        476.21
# 4        476.21
# ...         ...
# 269419   285.72
# 269420   274.78
# 269421   269.40
# 269422   264.07
# 269423   269.40
#
# [269424 rows x 1 columns]

# %%
input_regular = pd.concat([input_x_regular, ydata], axis = 1)
input_regular
# Out:
#          행주대교_유량   청담대교_수위    잠수교_수위   한강대교_수위   행주대교_수위  청담대교_유량
# 0       0.011070  0.049611  0.060000  0.051621  0.056478   469.05
# 1       0.011070  0.053502  0.060000  0.051621  0.056478   498.00
# 2       0.011070  0.052529  0.061111  0.051621  0.056478   490.68
# 3       0.011475  0.050584  0.061111  0.051621  0.058140   476.21
# 4       0.011883  0.050584  0.061111  0.052821  0.059801   476.21
# ...          ...       ...       ...       ...       ...      ...
# 269419  0.009498  0.021401  0.038889  0.037215  0.049834   285.72
# 269420  0.009884  0.019455  0.036667  0.037215  0.051495   274.78
# 269421  0.009884  0.018482  0.034444  0.036014  0.051495   269.40
# 269422  0.009498  0.017510  0.033333  0.034814  0.049834   264.07
# 269423  0.009116  0.018482  0.033333  0.033613  0.048173   269.40
#
# [269424 rows x 6 columns]

# %% [markdown]
# # 원하는 칼럼명 입력하기

# %%
input_y_ = input_regular[['청담대교_유량']]
input_x_ = input_regular.drop(input_y_.columns, axis = 1)

# %%
input_x_
# Out:
#          행주대교_유량   청담대교_수위    잠수교_수위   한강대교_수위   행주대교_수위
# 0       0.011070  0.049611  0.060000  0.051621  0.056478
# 1       0.011070  0.053502  0.060000  0.051621  0.056478
# 2       0.011070  0.052529  0.061111  0.051621  0.056478
# 3       0.011475  0.050584  0.061111  0.051621  0.058140
# 4       0.011883  0.050584  0.061111  0.052821  0.059801
# ...          ...       ...       ...       ...       ...
# 269419  0.009498  0.021401  0.038889  0.037215  0.049834
# 269420  0.009884  0.019455  0.036667  0.037215  0.051495
# 269421  0.009884  0.018482  0.034444  0.036014  0.051495
# 269422  0.009498  0.017510  0.033333  0.034814  0.049834
# 269423  0.009116  0.018482  0.033333  0.033613  0.048173
#
# [269424 rows x 5 columns]

# %%
input_y_.isnull().sum()
# Out:
# 청담대교_유량    15164
# dtype: int64

# %% [markdown]
# # 원하는 칼럼명 입력하기

# %%
nanIndex = input_y_[input_y_['청담대교_유량'].isnull() == True].index

# %%
nanIndex
# Out:
# Int64Index([ 80994,  80995,  80996,  80997,  80998,  80999,  81000,  81001,
#              81002,  81003,
#             ...
#             269321, 269322, 269323, 269324, 269325, 269326, 269327, 269328,
#             269329, 269406],
#            dtype='int64', length=15164)

# %%
from tqdm import tqdm

xdata = []
ydata = []
xdata_idx = []
ydata_idx = [-1]
for i in range(len(input_regular.columns)-1):
    xdata_idx.append(i)

w =  6 #window size

idx = []
for i in range(12):
  idx.append(i*26496)

for i in tqdm(range(11)):
    if i != 10:
        tmp = input_regular[idx[i]:idx[i+1]]
    else:
        tmp = input_regular[idx[i]:]

    for j in range(len(tmp)-w):
        xdata.append(np.array(tmp.iloc[j:j + w, xdata_idx]).astype(float))

    for j in range(w,len(tmp)):
        ydata.append(np.array(tmp.iloc[j, ydata_idx]).astype(float))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [03:37<00:00, 19.75s/it]

# %%
print(np.array(xdata).shape)
print(np.array(ydata).shape)
# Out:
# (269358, 6, 5)
# (269358, 1)

# %%
# 나중에 학습된 모델에 이거 넣어서 predict해서 결측치 채우기
x_real_predict = []
y_real_predict = []

for i in range(len(nanIndex)):
    k = nanIndex[-(i+1)]
    
    x_real_predict.insert(0,(xdata[k - w * (k // 26496 + 1)]))
    y_real_predict.insert(0,(ydata[k - w * (k // 26496 + 1)]))
    
    xdata.pop(k - 6 * (k // 26496 + 1))
    ydata.pop(k - 6 * (k // 26496 + 1))

# %%
print(np.array(x_real_predict).shape)
print(np.array(y_real_predict).shape)
# Out:
# (15164, 6, 5)
# (15164, 1)

# %%
y_real_predict
# Out:
# [array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  ...]

# %%
print(np.array(xdata).shape)
print(np.array(ydata).shape)
# Out:
# (254194, 6, 5)
# (254194, 1)

# %%
pd.DataFrame(ydata).isnull().sum()
# Out:
# 0    0
# dtype: int64

# %%
xtrain = np.array(xdata[:-50000])
ytrain = np.array(ydata[:-50000])

xtest = np.array(xdata[-50000:])
ytest = np.array(ydata[-50000:])

# %%
print(xtrain.shape)
print(ytrain.shape)
print(xtest.shape)
print(ytest.shape)
# Out:
# (204194, 6, 5)
# (204194, 1)
# (50000, 6, 5)
# (50000, 1)

# %% [markdown]
# ## 모델 생성

# %%
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true))) 

if 'model_enc_dec_cnn' in locals(): 
    del model_enc_dec_cnn 
if 'history' in locals():
    del history

optimizer = tf.keras.optimizers.Adam(lr=0.01) #기본값 0.001

model_enc_dec_cnn = Sequential()
model_enc_dec_cnn.add(Conv1D(filters=64, kernel_size=2, padding = 'causal', activation='relu', input_shape=(w, xtrain.shape[2])))
#model_enc_dec_cnn.add(Conv1D(filters=64, kernel_size=2, padding = 'causal', activation='relu'))
#model_enc_dec_cnn.add(MaxPooling1D(pool_size=2))
model_enc_dec_cnn.add(Flatten())

model_enc_dec_cnn.add(RepeatVector(1))
model_enc_dec_cnn.add(LSTM(200, activation='relu', return_sequences=True))
model_enc_dec_cnn.add(LSTM(200, activation='relu', return_sequences=True))
model_enc_dec_cnn.add(LSTM(200, activation='relu', return_sequences=True))
model_enc_dec_cnn.add(LSTM(200, activation='relu', return_sequences=True))
model_enc_dec_cnn.add(LSTM(200, activation='relu', return_sequences=True))
model_enc_dec_cnn.add(LSTM(200, activation='relu'))

model_enc_dec_cnn.add(Dense(100, activation='relu'))
model_enc_dec_cnn.add(Dense(1))

model_enc_dec_cnn.compile(loss=root_mean_squared_error, optimizer=optimizer, metrics =["accuracy"])

model_enc_dec_cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 6, 64)             704
#
#  flatten (Flatten)           (None, 384)               0
#
#  repeat_vector (RepeatVector  (None, 1, 384)           0
#  )
#
#  lstm (LSTM)                 (None, 1, 200)            468000
#
#  lstm_1 (LSTM)               (None, 1, 200)            320800
#
#  lstm_2 (LSTM)               (None, 1, 200)            320800
#
#  lstm_3 (LSTM)               (None, 1, 200)            320800
#
#  lstm_4 (LSTM)               (None, 1, 200)            320800
#
#  lstm_5 (LSTM)               (None, 200)               320800
#
#  dense (Dense)               (None, 100)               20100
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 2,092,905
# Trainable params: 2,092,905
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model=model_enc_dec_cnn, show_shapes=True)

# %%
epochs = 100
batch_size = xtrain.shape[0] // 1000
validation = 0.2

checkpoint_callback = ModelCheckpoint(filepath='best_model.h5', save_weights_only=False, monitor='val_loss',
                                         mode='min', save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', min_delta=0.005, patience=10, mode='min')
rlrop_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, mode='min', patience=3, min_lr=0.001)

# %%
## 학습

history = model_enc_dec_cnn.fit(xtrain, ytrain, verbose=1, epochs=epochs, batch_size=batch_size, validation_split=validation,callbacks=[early_stopping_callback, checkpoint_callback, rlrop_callback])
# Out:
# Epoch 1/100
# 801/801 [==============================] - 74s 68ms/step - loss: 232.2724 - accuracy: 0.0000e+00 - val_loss: 37.1911 - val_accuracy: 0.0000e+00 - lr: 0.0100
# Epoch 2/100
# 801/801 [==============================] - 52s 65ms/step - loss: 103.5309 - accuracy: 0.0000e+00 - val_loss: 36.4978 - val_accuracy: 0.0000e+00 - lr: 0.0100
# Epoch 3/100
# 801/801 [==============================] - 51s 64ms/step - loss: 86.0758 - accuracy: 0.0000e+00 - val_loss: 23.7532 - val_accuracy: 0.0000e+00 - lr: 0.0100
# Epoch 4/100
# 801/801 [==============================] - 51s 64ms/step - loss: 73.9831 - accuracy: 0.0000e+00 - val_loss: 25.0220 - val_accuracy: 0.0000e+00 - lr: 0.0100
# Epoch 5/100
# 801/801 [==============================] - 51s 63ms/step - loss: 63.1547 - accuracy: 0.0000e+00 - val_loss: 26.2554 - val_accuracy: 0.0000e+00 - lr: 0.0100
# Epoch 6/100
# 801/801 [==============================] - 51s 63ms/step - loss: 62.6732 - accuracy: 0.0000e+00 - val_loss: 39.8650 - val_accuracy: 0.0000e+00 - lr: 0.0100
# Epoch 7/100
# 801/801 [==============================] - 52s 65ms/step - loss: 36.8386 - accuracy: 0.0000e+00 - val_loss: 14.8944 - val_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 8/100
# 801/801 [==============================] - 51s 63ms/step - loss: 35.7402 - accuracy: 0.0000e+00 - val_loss: 19.9865 - val_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 9/100
# 801/801 [==============================] - 34s 42ms/step - loss: 33.1805 - accuracy: 0.0000e+00 - val_loss: 18.4543 - val_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 10/100
# 801/801 [==============================] - 27s 33ms/step - loss: 37.3530 - accuracy: 0.0000e+00 - val_loss: 12.8878 - val_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 11/100
# 801/801 [==============================] - 28s 34ms/step - loss: 34.7980 - accuracy: 0.0000e+00 - val_loss: 16.6474 - val_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 12/100
# 801/801 [==============================] - 27s 34ms/step - loss: 31.9864 - accuracy: 0.0000e+00 - val_loss: 12.1270 - val_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 13/100
# 801/801 [==============================] - 27s 34ms/step - loss: 34.9556 - accuracy: 0.0000e+00 - val_loss: 12.5641 - val_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 14/100
# 801/801 [==============================] - 28s 34ms/step - loss: 29.0776 - accuracy: 0.0000e+00 - val_loss: 18.5381 - val_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 15/100
# 801/801 [==============================] - 27s 33ms/step - loss: 32.3888 - accuracy: 0.0000e+00 - val_loss: 13.4288 - val_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 16/100
# 801/801 [==============================] - 28s 35ms/step - loss: 22.9080 - accuracy: 0.0000e+00 - val_loss: 12.4248 - val_accuracy: 0.0000e+00 - lr: 0.0025
# Epoch 17/100
# 801/801 [==============================] - 28s 35ms/step - loss: 22.2672 - accuracy: 0.0000e+00 - val_loss: 11.5726 - val_accuracy: 0.0000e+00 - lr: 0.0025
# Epoch 18/100
# 801/801 [==============================] - 28s 35ms/step - loss: 22.4827 - accuracy: 0.0000e+00 - val_loss: 10.1146 - val_accuracy: 0.0000e+00 - lr: 0.0025
# Epoch 19/100
# 801/801 [==============================] - 28s 35ms/step - loss: 23.0920 - accuracy: 0.0000e+00 - val_loss: 10.5782 - val_accuracy: 0.0000e+00 - lr: 0.0025
# Epoch 20/100
# 801/801 [==============================] - 28s 34ms/step - loss: 22.8405 - accuracy: 0.0000e+00 - val_loss: 15.3069 - val_accuracy: 0.0000e+00 - lr: 0.0025
# Epoch 21/100
# 801/801 [==============================] - 27s 34ms/step - loss: 22.1071 - accuracy: 0.0000e+00 - val_loss: 11.4079 - val_accuracy: 0.0000e+00 - lr: 0.0025
# Epoch 22/100
# 801/801 [==============================] - 27s 34ms/step - loss: 18.9073 - accuracy: 0.0000e+00 - val_loss: 11.0120 - val_accuracy: 0.0000e+00 - lr: 0.0012
# Epoch 23/100
# 801/801 [==============================] - 28s 34ms/step - loss: 18.9045 - accuracy: 0.0000e+00 - val_loss: 9.5972 - val_accuracy: 0.0000e+00 - lr: 0.0012
# Epoch 24/100
# 801/801 [==============================] - 28s 34ms/step - loss: 18.8020 - accuracy: 0.0000e+00 - val_loss: 10.0590 - val_accuracy: 0.0000e+00 - lr: 0.0012
# Epoch 25/100
# 801/801 [==============================] - 28s 34ms/step - loss: 19.3834 - accuracy: 0.0000e+00 - val_loss: 9.6733 - val_accuracy: 0.0000e+00 - lr: 0.0012
# Epoch 26/100
# 801/801 [==============================] - 27s 34ms/step - loss: 18.5901 - accuracy: 0.0000e+00 - val_loss: 12.1607 - val_accuracy: 0.0000e+00 - lr: 0.0012
# Epoch 27/100
# 801/801 [==============================] - 28s 34ms/step - loss: 18.1656 - accuracy: 0.0000e+00 - val_loss: 10.5684 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 28/100
# 801/801 [==============================] - 28s 35ms/step - loss: 18.2023 - accuracy: 0.0000e+00 - val_loss: 9.5737 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 29/100
# 801/801 [==============================] - 28s 34ms/step - loss: 17.7699 - accuracy: 0.0000e+00 - val_loss: 14.6651 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 30/100
# 801/801 [==============================] - 27s 34ms/step - loss: 18.2712 - accuracy: 0.0000e+00 - val_loss: 9.6214 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 31/100
# 801/801 [==============================] - 28s 35ms/step - loss: 17.9715 - accuracy: 0.0000e+00 - val_loss: 11.0654 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 32/100
# 801/801 [==============================] - 28s 35ms/step - loss: 18.2157 - accuracy: 0.0000e+00 - val_loss: 9.3036 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 33/100
# 801/801 [==============================] - 28s 35ms/step - loss: 17.8024 - accuracy: 0.0000e+00 - val_loss: 10.6307 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 34/100
# 801/801 [==============================] - 28s 35ms/step - loss: 17.7143 - accuracy: 0.0000e+00 - val_loss: 13.7545 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 35/100
# 801/801 [==============================] - 28s 35ms/step - loss: 17.9116 - accuracy: 0.0000e+00 - val_loss: 9.7244 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 36/100
# 801/801 [==============================] - 27s 34ms/step - loss: 17.4612 - accuracy: 0.0000e+00 - val_loss: 9.6529 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 37/100
# 801/801 [==============================] - 27s 34ms/step - loss: 17.8906 - accuracy: 0.0000e+00 - val_loss: 10.0913 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 38/100
# 801/801 [==============================] - 27s 34ms/step - loss: 17.7943 - accuracy: 0.0000e+00 - val_loss: 10.2647 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 39/100
# 801/801 [==============================] - 27s 34ms/step - loss: 17.7521 - accuracy: 0.0000e+00 - val_loss: 11.1072 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 40/100
# 801/801 [==============================] - 27s 34ms/step - loss: 17.7163 - accuracy: 0.0000e+00 - val_loss: 9.4398 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 41/100
# 801/801 [==============================] - 27s 34ms/step - loss: 17.3270 - accuracy: 0.0000e+00 - val_loss: 10.0687 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 42/100
# 801/801 [==============================] - 27s 34ms/step - loss: 17.6783 - accuracy: 0.0000e+00 - val_loss: 9.8721 - val_accuracy: 0.0000e+00 - lr: 0.0010

# %%
## 평가

keras_model_best = keras.models.load_model('best_model.h5', custom_objects={'root_mean_squared_error': root_mean_squared_error})

yhat = keras_model_best.predict(xtest, verbose=1)

yhat

keras_model_best.evaluate(xtest,ytest)
# Out:
# 1563/1563 [==============================] - 13s 8ms/step
# 1563/1563 [==============================] - 14s 9ms/step - loss: 13.5533 - accuracy: 0.0000e+00
# [13.553328514099121, 0.0]

# %%
## 학습 과정 시각화

fig, loss_ax = plt.subplots(1, 2)
fig.set_size_inches((15,5))

loss_ax[0].plot(history.history['loss'], 'b', label='train loss')
loss_ax[0].plot(history.history['val_loss'], 'r', label='val loss')

loss_ax[1].plot(history.history['accuracy'], 'y', label='train acc')
loss_ax[1].plot(history.history['val_accuracy'], 'g', label='val acc')

loss_ax[0].set_xlabel('epoch')
loss_ax[0].set_ylabel('loss')
loss_ax[1].set_xlabel('epoch')
loss_ax[1].set_ylabel('accuray')

loss_ax[0].legend(loc='upper right')
loss_ax[1].legend(loc='lower right')

plt.show()

# %%
## 결과 시각화

tl_predict = np.array(yhat)

#결과 시각화
plt.figure(figsize=(15,10))
plt.plot(ytest, marker = ",", label = "actual")
plt.plot(tl_predict, marker = ",", label="predict", alpha = 0.5)
plt.legend(prop={'size':10})  

plt.show()

# %%
## 점수 확인
print("RMSE : ",float(root_mean_squared_error(ytest, tl_predict)))
# Out:
# RMSE :  16.58322120239108

# %% [markdown]
# ## 파일 저장
# 파일명에 '완성' 없으면 마지막 6912개는 raw data

# %% [markdown]
# # 원하는 칼럼명 입력하기

# %%
raw_data2 = pd.read_csv('C:/Users/sjkan/Desktop/연세/YBIGTA/22 여름방학/신입기수프로젝트/rawdata.csv')
raw_data2 = raw_data2[:-6912]
predict_dataset = raw_data2['청담대교_유량']

# %%
predict_dataset.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 269424 entries, 0 to 269423
# Series name: 청담대교_유량
# Non-Null Count   Dtype
# --------------   -----
# 254260 non-null  float64
# dtypes: float64(1)
# memory usage: 2.1 MB

# %%
predict_dataset.isnull().sum()
# Out:
# 15164

# %%
predict_dataset.iloc[nanIndex[2]]
# Out:
# nan

# %%
y_real_predict
# Out:
# [array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  array([nan]),
#  ...]

# %%
test_input = np.array(x_real_predict)
y_real_hat = keras_model_best.predict(test_input, verbose=1)
# Out:
# 474/474 [==============================] - 4s 8ms/step

# %%
y_real_hat
# Out:
# array([[244.72156],
#        [244.43257],
#        [244.32616],
#        ...,
#        [243.58379],
#        [243.49135],
#        [246.79099]], dtype=float32)

# %%
predict_dataset.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 269424 entries, 0 to 269423
# Series name: 청담대교_유량
# Non-Null Count   Dtype
# --------------   -----
# 254260 non-null  float64
# dtypes: float64(1)
# memory usage: 2.1 MB

# %%
predict_dataset.isnull().sum()
# Out:
# 15164

# %%
for i in range(len(nanIndex)):
    predict_dataset.iloc[nanIndex[i]] = np.float64(y_real_hat[i])

# %%
predict_dataset.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 269424 entries, 0 to 269423
# Series name: 청담대교_유량
# Non-Null Count   Dtype
# --------------   -----
# 269424 non-null  float64
# dtypes: float64(1)
# memory usage: 2.1 MB

# %%
predict_dataset.isnull().sum()
# Out:
# 0

# %% [markdown]
# # 원하는 칼럼명 입력하기

# %%
addon = pd.read_csv('C:/Users/sjkan/Desktop/연세/YBIGTA/22 여름방학/신입기수프로젝트/rawdata.csv')
addon.set_index(keys = ['날짜'], inplace = True)
addon.index = pd.to_datetime(addon.index, format = '%Y-%m-%d %H:%M')
add = addon[['청담대교_유량']][-6912:]
add = add.reset_index()
add = add['청담대교_유량']
add = pd.DataFrame(add)
add
# Out:
#       청담대교_유량
# 0      269.40
# 1      280.22
# 2      296.87
# 3      302.53
# 4      296.87
# ...       ...
# 6907   319.84
# 6908   314.01
# 6909   387.55
# 6910   454.91
# 6911   582.21
#
# [6912 rows x 1 columns]

# %%
result = pd.concat([pd.DataFrame(predict_dataset), add], ignore_index = True)
result
# Out:
#         청담대교_유량
# 0        469.05
# 1        498.00
# 2        490.68
# 3        476.21
# 4        476.21
# ...         ...
# 276331   319.84
# 276332   314.01
# 276333   387.55
# 276334   454.91
# 276335   582.21
#
# [276336 rows x 1 columns]

# %%
result.to_csv('청담대교_유량.csv', index = False, encoding = 'cp949', columns = ['청담대교_유량'])
