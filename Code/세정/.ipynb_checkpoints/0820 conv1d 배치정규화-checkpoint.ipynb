# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')

import time
from glob import glob
from tqdm import tqdm
from scipy import interpolate

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Activation, Dense, LSTM, GRU, AveragePooling1D, GlobalAveragePooling1D, Dropout, Flatten, BatchNormalization
from keras.layers.convolutional import Conv1D, MaxPooling1D, AveragePooling1D 
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import backend as K

#GPU 자원이 부족
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
## 1. 데이터 불러오기, 공통 전처리
raw_data = pd.read_csv('/Volumes/GoogleDrive/.shortcut-targets-by-id/1rUx7_7LmBqAQTbWEWVTGvw0_d0v6N2ZT/신입기수 프로젝트/Dataset/rawdata.csv')

###유량 처리
유량 = pd.read_csv('/Volumes/GoogleDrive/.shortcut-targets-by-id/1rUx7_7LmBqAQTbWEWVTGvw0_d0v6N2ZT/신입기수 프로젝트/Dataset/잠수교_유량_수위_보간/청담대교_cuve_fit.csv', encoding='cp949')
유량 = 유량.iloc[:,[2,4,6,8]]
유량 = 유량.interpolate()
_raw_data = pd.concat((raw_data.drop(유량.columns,axis=1), 유량),axis=1)
raw_data = _raw_data

###유입량, 저수량 제거
raw_data_ = raw_data.drop(raw_data[['유입량','저수량','대곡교_강수량','진관교_강수량','송정동_강수량','잠수교_유량']], axis = 1)

###강화대교 조위 시간차
강화대교_조위 = pd.read_csv('C:/Users/sjkan/Desktop/연세/YBIGTA/22 여름방학/신입기수프로젝트/tide_level_all.csv', encoding='cp949')
raw_data__ = pd.concat((raw_data_.drop(강화대교_조위.columns,axis=1),강화대교_조위),axis=1)

###방류량 조위 시간차
방류량 = pd.read_csv('C:/Users/sjkan/Desktop/연세/YBIGTA/22 여름방학/신입기수프로젝트/방류량 for 전체.csv', encoding='cp949')
__raw_data = pd.concat((raw_data__.drop(방류량.columns,axis=1),방류량),axis=1)
raw_data___ = __raw_data.set_index('날짜',drop=True)

###보간 처리
보간처리 = raw_data___[['현재수위','공용량','방류량','강화대교_조위', '청담대교_유량', '한강대교_유량', '행주대교_유량', '청담대교_수위', '잠수교_수위', '한강대교_수위', '행주대교_수위']].interpolate(method = 'linear' , limit_direction = 'forward')
보간처리df = pd.concat([raw_data___.drop(보간처리.columns, axis = 1), 보간처리], axis=1)

input_y = 보간처리df[['청담대교_수위','잠수교_수위','한강대교_수위','행주대교_수위']]
input_x = 보간처리df.drop(input_y.columns, axis = 1)

#train / test data 생성
idx = []
for i in range(12):
  idx.append(i*26496)

# %%
보간처리df
# Out:
#                     현재수위    공용량     방류량  강화대교_조위  청담대교_유량  한강대교_유량  행주대교_유량  \
# 날짜
# 2012-05-01 00:00  24.800  24.93  575.70    193.0   469.05   729.80   540.18
# 2012-05-01 00:10  24.794  25.15  575.30    199.0   498.00   731.48   540.18
# 2012-05-01 00:20  24.789  25.31  555.00    207.0   490.68   726.42   540.18
# 2012-05-01 00:30  24.789  25.31  575.70    215.0   476.21   726.42   552.17
# 2012-05-01 00:40  24.789  25.31  575.40    226.0   476.21   707.17   564.29
# ...                  ...    ...     ...      ...      ...      ...      ...
# 2022-07-18 23:10  25.040  31.14  258.67    407.0   319.84  -456.41   974.40
# 2022-07-18 23:20  25.040  31.14  258.58    431.0   314.01  -717.30  1006.88
# 2022-07-18 23:30  25.040  31.14  258.56    453.0   387.55  -843.37  1039.90
# 2022-07-18 23:40  25.040  31.14  258.65    476.0   454.91 -1023.37  1073.46
# 2022-07-18 23:50  25.040  31.14  258.09    499.0   582.21 -1049.44  1090.45
#
#                   청담대교_수위  잠수교_수위  한강대교_수위  행주대교_수위
# 날짜
# 2012-05-01 00:00    310.7   300.2    290.0    275.3
# 2012-05-01 00:10    314.7   300.2    290.0    275.3
# 2012-05-01 00:20    313.7   301.2    290.0    275.3
# 2012-05-01 00:30    311.7   301.2    290.0    276.3
# 2012-05-01 00:40    311.7   301.2    291.0    277.3
# ...                   ...     ...      ...      ...
# 2022-07-18 23:10      0.0     0.0      0.0      0.0
# 2022-07-18 23:20      0.0     0.0      0.0      0.0
# 2022-07-18 23:30      0.0     0.0      0.0      0.0
# 2022-07-18 23:40      0.0     0.0      0.0      0.0
# 2022-07-18 23:50      0.0     0.0      0.0      0.0
#
# [276336 rows x 11 columns]

# %%
start = time.time()

y_predict = []

ytest_list = sorted(glob("C:/Users/sjkan/Desktop/submission 임시/*.csv"))

ytest = []

for i in range(len(ytest_list)):
  tmp = pd.read_csv(ytest_list[i], encoding = 'cp949')
  ytest.append(np.array(tmp.iloc[:,1])*100)


xdata = []
ydata = []
xdata_idx = []
ydata_idx = [-4,-3,-2,-1]
for i in range(len(보간처리df.columns)-4):
    xdata_idx.append(i)

w =  432 #window size

for i in tqdm(range(11)):
    if i != 10:
        tmp = 보간처리df[idx[i]:idx[i+1]]
    else:
        tmp = 보간처리df[idx[i]:]

    for j in range(len(tmp)-w+1):
        xdata.append(np.array(tmp.iloc[j:j + w, xdata_idx]).astype(float))

    for j in range(w-1,len(tmp)):
        ydata.append(np.array(tmp.iloc[j, ydata_idx]).astype(float))

xdata_ = np.array(xdata)
ydata_ = np.array(ydata)

xtrain = xdata_[:-6912]
ytrain = ydata_[:-6912]
xtest = xdata_[-6912:]
#ytest = ydata_[-6912:]
    
# 모델링 및 모델 학습

if 'model' in locals(): 
    del model 
if 'history' in locals():
    del history

model = Sequential()
model.add(Conv1D(filters = 8, input_shape = (w, len(보간처리df.columns)-4), kernel_size = 2, padding='causal', dilation_rate=2))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))  #0.2~0.5  0.8까지

model.add(Conv1D(filters = 16, kernel_size = 2, padding='causal', dilation_rate=4))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

#model.add(MaxPooling1D(pool_size=2))
model.add(AveragePooling1D(pool_size=2))

model.add(Conv1D(filters = 32, kernel_size = 2, padding='causal', dilation_rate=8))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Conv1D(filters = 32, kernel_size = 1))

model.add(Flatten())

model.add(Dense(50))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Dense(4))


def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true))) 

model.compile(optimizer='adam', loss=root_mean_squared_error, metrics =["accuracy"])
model.summary()



callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss',
                                            patience=10),
                keras.callbacks.ModelCheckpoint(filepath='best_model.h5',
                                                monitor='val_loss',
                                                save_best_only=True)]

history = model.fit(xtrain, ytrain, epochs=300, verbose=1, validation_split=0.2, callbacks=callbacks, batch_size = 3742) #batch size..?


keras_model_best = keras.models.load_model('best_model.h5', custom_objects={'root_mean_squared_error': root_mean_squared_error})

keras_model_best.evaluate(xtest,ytest)

y_predict.append(keras_model_best.predict(xtest))

print("time :", time.time() - start, "초")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [01:38<00:00,  8.93s/it]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 432, 8)            120
#
#  batch_normalization (BatchN  (None, 432, 8)           32
#  ormalization)
#
#  activation (Activation)     (None, 432, 8)            0
#
#  dropout (Dropout)           (None, 432, 8)            0
#
#  conv1d_1 (Conv1D)           (None, 432, 16)           272
#
#  batch_normalization_1 (Batc  (None, 432, 16)          64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 432, 16)           0
#
#  dropout_1 (Dropout)         (None, 432, 16)           0
#
#  average_pooling1d (AverageP  (None, 216, 16)          0
#  ooling1D)
#
#  conv1d_2 (Conv1D)           (None, 216, 32)           1056
#
#  batch_normalization_2 (Batc  (None, 216, 32)          128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 216, 32)           0
#
#  dropout_2 (Dropout)         (None, 216, 32)           0
#
#  conv1d_3 (Conv1D)           (None, 216, 32)           1056
#
#  flatten (Flatten)           (None, 6912)              0
#
#  dense (Dense)               (None, 50)                345650
#
#  batch_normalization_3 (Batc  (None, 50)               200
#  hNormalization)
#
#  activation_3 (Activation)   (None, 50)                0
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense_1 (Dense)             (None, 4)                 204
#
# =================================================================
# Total params: 348,782
# Trainable params: 348,570
# Non-trainable params: 212
# _________________________________________________________________
# Epoch 1/300
# 57/57 [==============================] - 253s 4s/step - loss: 316.7557 - accuracy: 0.3046 - val_loss: 328.5515 - val_accuracy: 0.5130
# Epoch 2/300
# 57/57 [==============================] - 227s 4s/step - loss: 315.0561 - accuracy: 0.3890 - val_loss: 327.0807 - val_accuracy: 0.2292
# Epoch 3/300
# 57/57 [==============================] - 225s 4s/step - loss: 312.8056 - accuracy: 0.3692 - val_loss: 324.2083 - val_accuracy: 0.1255
# Epoch 4/300
# 57/57 [==============================] - 224s 4s/step - loss: 309.8508 - accuracy: 0.3716 - val_loss: 321.2257 - val_accuracy: 0.2177
# Epoch 5/300
# 57/57 [==============================] - 188s 3s/step - loss: 306.0886 - accuracy: 0.3851 - val_loss: 317.6981 - val_accuracy: 0.3161
# Epoch 6/300
# 57/57 [==============================] - 196s 3s/step - loss: 301.5086 - accuracy: 0.3913 - val_loss: 313.6017 - val_accuracy: 0.4160
# Epoch 7/300
# 57/57 [==============================] - 189s 3s/step - loss: 296.1069 - accuracy: 0.3856 - val_loss: 306.2268 - val_accuracy: 0.4268
# Epoch 8/300
# 57/57 [==============================] - 192s 3s/step - loss: 289.9301 - accuracy: 0.3868 - val_loss: 299.4125 - val_accuracy: 0.3935
# Epoch 9/300
# 57/57 [==============================] - 193s 3s/step - loss: 282.9835 - accuracy: 0.3900 - val_loss: 293.3058 - val_accuracy: 0.3609
# Epoch 10/300
# 57/57 [==============================] - 192s 3s/step - loss: 275.3416 - accuracy: 0.3999 - val_loss: 284.7871 - val_accuracy: 0.3411
# Epoch 11/300
# 57/57 [==============================] - 189s 3s/step - loss: 266.9933 - accuracy: 0.4149 - val_loss: 272.8159 - val_accuracy: 0.3695
# Epoch 12/300
# 57/57 [==============================] - 187s 3s/step - loss: 258.0384 - accuracy: 0.4193 - val_loss: 261.3232 - val_accuracy: 0.3686
# Epoch 13/300
# 57/57 [==============================] - 185s 3s/step - loss: 248.4395 - accuracy: 0.4254 - val_loss: 250.9601 - val_accuracy: 0.3506
# Epoch 14/300
# 57/57 [==============================] - 186s 3s/step - loss: 238.2377 - accuracy: 0.4352 - val_loss: 237.9272 - val_accuracy: 0.3592
# Epoch 15/300
# 57/57 [==============================] - 182s 3s/step - loss: 227.3752 - accuracy: 0.4518 - val_loss: 231.6600 - val_accuracy: 0.3266
# Epoch 16/300
# 57/57 [==============================] - 178s 3s/step - loss: 215.9308 - accuracy: 0.4726 - val_loss: 226.1375 - val_accuracy: 0.3221
# Epoch 17/300
# 57/57 [==============================] - 192s 3s/step - loss: 203.7213 - accuracy: 0.5055 - val_loss: 219.2448 - val_accuracy: 0.4274
# Epoch 18/300
# 57/57 [==============================] - 186s 3s/step - loss: 190.8469 - accuracy: 0.5301 - val_loss: 199.8274 - val_accuracy: 0.4670
# Epoch 19/300
# 57/57 [==============================] - 203s 4s/step - loss: 177.6451 - accuracy: 0.5559 - val_loss: 186.7958 - val_accuracy: 0.4871
# Epoch 20/300
# 57/57 [==============================] - 213s 4s/step - loss: 163.8980 - accuracy: 0.5876 - val_loss: 166.1073 - val_accuracy: 0.5061
# Epoch 21/300
# 57/57 [==============================] - 207s 4s/step - loss: 149.8219 - accuracy: 0.6240 - val_loss: 148.5703 - val_accuracy: 0.5121
# Epoch 22/300
# 57/57 [==============================] - 202s 4s/step - loss: 135.2626 - accuracy: 0.6617 - val_loss: 139.3970 - val_accuracy: 0.5168
# Epoch 23/300
# 57/57 [==============================] - 209s 4s/step - loss: 120.2537 - accuracy: 0.6995 - val_loss: 114.5131 - val_accuracy: 0.5305
# Epoch 24/300
# 57/57 [==============================] - 217s 4s/step - loss: 104.9328 - accuracy: 0.7258 - val_loss: 99.3143 - val_accuracy: 0.5484
# Epoch 25/300
# 57/57 [==============================] - 215s 4s/step - loss: 89.6657 - accuracy: 0.7496 - val_loss: 72.6348 - val_accuracy: 0.5500
# Epoch 26/300
# 57/57 [==============================] - 219s 4s/step - loss: 73.6814 - accuracy: 0.7760 - val_loss: 64.5162 - val_accuracy: 0.5440
# Epoch 27/300
# 57/57 [==============================] - 225s 4s/step - loss: 58.1556 - accuracy: 0.7981 - val_loss: 53.4276 - val_accuracy: 0.5333
# Epoch 28/300
# 57/57 [==============================] - 215s 4s/step - loss: 44.4246 - accuracy: 0.8299 - val_loss: 34.4442 - val_accuracy: 0.5554
# Epoch 29/300
# 57/57 [==============================] - 220s 4s/step - loss: 35.5817 - accuracy: 0.8629 - val_loss: 28.5395 - val_accuracy: 0.5769
# Epoch 30/300
# 57/57 [==============================] - 218s 4s/step - loss: 31.3366 - accuracy: 0.8888 - val_loss: 23.7152 - val_accuracy: 0.5884
# Epoch 31/300
# 57/57 [==============================] - 216s 4s/step - loss: 30.0515 - accuracy: 0.9073 - val_loss: 23.3875 - val_accuracy: 0.6008
# Epoch 32/300
# 57/57 [==============================] - 218s 4s/step - loss: 29.4073 - accuracy: 0.9177 - val_loss: 17.2926 - val_accuracy: 0.6029
# Epoch 33/300
# 57/57 [==============================] - 229s 4s/step - loss: 29.2960 - accuracy: 0.9233 - val_loss: 18.0887 - val_accuracy: 0.6042
# Epoch 34/300
# 57/57 [==============================] - 216s 4s/step - loss: 28.7493 - accuracy: 0.9265 - val_loss: 16.7596 - val_accuracy: 0.6044
# Epoch 35/300
# 57/57 [==============================] - 216s 4s/step - loss: 28.6109 - accuracy: 0.9280 - val_loss: 15.2430 - val_accuracy: 0.6044
# Epoch 36/300
# 57/57 [==============================] - 219s 4s/step - loss: 28.3471 - accuracy: 0.9292 - val_loss: 14.1628 - val_accuracy: 0.6044
# Epoch 37/300
# 57/57 [==============================] - 221s 4s/step - loss: 28.1549 - accuracy: 0.9297 - val_loss: 13.2836 - val_accuracy: 0.6044
# Epoch 38/300
# 57/57 [==============================] - 201s 4s/step - loss: 27.9795 - accuracy: 0.9316 - val_loss: 16.3207 - val_accuracy: 0.6044
# Epoch 39/300
# 57/57 [==============================] - 214s 4s/step - loss: 27.8882 - accuracy: 0.9348 - val_loss: 15.5468 - val_accuracy: 0.6056
# Epoch 40/300
# 57/57 [==============================] - 213s 4s/step - loss: 27.5765 - accuracy: 0.9398 - val_loss: 16.3620 - val_accuracy: 0.6085
# Epoch 41/300
# 57/57 [==============================] - 207s 4s/step - loss: 27.5551 - accuracy: 0.9439 - val_loss: 15.4998 - val_accuracy: 0.6115
# Epoch 42/300
# 57/57 [==============================] - 199s 3s/step - loss: 27.4288 - accuracy: 0.9473 - val_loss: 15.0312 - val_accuracy: 0.6131
# Epoch 43/300
# 57/57 [==============================] - 199s 3s/step - loss: 27.3896 - accuracy: 0.9502 - val_loss: 13.3533 - val_accuracy: 0.6147
# Epoch 44/300
# 57/57 [==============================] - 196s 3s/step - loss: 27.2563 - accuracy: 0.9520 - val_loss: 13.5058 - val_accuracy: 0.6204
# Epoch 45/300
# 57/57 [==============================] - 196s 3s/step - loss: 27.1238 - accuracy: 0.9536 - val_loss: 14.8627 - val_accuracy: 0.6199
# Epoch 46/300
# 57/57 [==============================] - 196s 3s/step - loss: 27.1483 - accuracy: 0.9544 - val_loss: 13.6989 - val_accuracy: 0.6257
# Epoch 47/300
# 57/57 [==============================] - 196s 3s/step - loss: 26.9602 - accuracy: 0.9550 - val_loss: 15.6081 - val_accuracy: 0.6246
# 216/216 [==============================] - 2s 5ms/step - loss: 23.0471 - accuracy: 1.0000
# 216/216 [==============================] - 1s 4ms/step
# time : 9795.386281013489 초

# %%
#학습 과정 표시하기
# %matplotlib inline
fig, loss_ax = plt.subplots(1, 2)
fig.set_size_inches((15,5))

loss_ax[0].plot(history.history['loss'], 'b', label='train loss')
loss_ax[0].plot(history.history['val_loss'], 'r', label='val loss')

loss_ax[1].plot(history.history['accuracy'], 'y', label='train acc')
loss_ax[1].plot(history.history['val_accuracy'], 'g', label='val acc')

loss_ax[0].set_xlabel('epoch')
loss_ax[0].set_ylabel('loss')
loss_ax[1].set_xlabel('epoch')
loss_ax[1].set_ylabel('accuray')

loss_ax[0].legend(loc='upper right')
loss_ax[1].legend(loc='lower right')

plt.show()

# %%
tl_predict = np.array(y_predict).reshape(6912,4).T

#결과 시각화
f, axes = plt.subplots(4, 1)
f.set_size_inches((20, 35))
plt.subplots_adjust(wspace = 0.3, hspace = 0.3)

for i in range(4):
    axes[i].plot(ytest[i], marker = ",", label = "actual")
    axes[i].plot(tl_predict[i], marker = ",", label="predict")
    axes[i].legend(prop={'size':10})  

plt.show()

# %%
#점수 채점하기
score = []
for i in range(4):
    print(root_mean_squared_error(ytest[i], tl_predict[i]))
    score.append(root_mean_squared_error(ytest[i], tl_predict[i]))
    
print("최종점수: ", np.mean(score))
# Out:
# tf.Tensor(16.536513958542052, shape=(), dtype=float64)
# tf.Tensor(11.278491782679344, shape=(), dtype=float64)
# tf.Tensor(10.44365501848827, shape=(), dtype=float64)
# tf.Tensor(10.697586606590793, shape=(), dtype=float64)
# 최종점수:  12.239061841575115

# %%
#제출 파일 생성

sample_submission = pd.read_csv("C:/Users/sjkan/Desktop/연세/YBIGTA/22 여름방학/신입기수프로젝트/sample_submission.csv")

sample_submission["wl_1018662"] = tl_predict[0]
sample_submission["wl_1018680"] = tl_predict[1]
sample_submission["wl_1018683"] = tl_predict[2]
sample_submission["wl_1019630"] = tl_predict[3]

sample_submission.to_csv("0820 conv1d.csv", index = False)

# %%
#결과: 12.9208469187
