# %% [markdown]
# ### 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')

# %%
import time
from glob import glob
from tqdm import tqdm
from scipy import interpolate

# %%
# train, test data 생성할 때 필요
from sklearn.model_selection import train_test_split
# 정규화할 때 필요
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
# conda install tensorflow

# %%
# conda install python=3.7

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Activation, Dense, LSTM, GRU, AveragePooling1D, GlobalAveragePooling1D, Dropout, Flatten, BatchNormalization
from keras.layers.convolutional import Conv1D, MaxPooling1D, AveragePooling1D 
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import backend as K

# %% [markdown]
# ### 청담대교_유량 데이터 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 데이터 불러오기 
전체df = pd.read_csv('/content/drive/MyDrive/신입기수 프로젝트/Dataset/잠수교_유량_수위_보간/청담대교_cuve_fit.csv', encoding = 'cp949')
# for colab
# /content/drive/MyDrive/신입기수 프로젝트/Dataset/잠수교_유량_수위_보간/청담대교_cuve_fit.csv
# for jupyter
# /Volumes/GoogleDrive/.shortcut-targets-by-id/1rUx7_7LmBqAQTbWEWVTGvw0_d0v6N2ZT/신입기수 프로젝트/Dataset/rawdata.csv

# %%
청담대교_유량 = 전체df['청담대교_유량']

# %%
청담대교_유량
# Out:
# 0         469.05
# 1         498.00
# 2         490.68
# 3         476.21
# 4         476.21
#            ...
# 276331    319.84
# 276332    314.01
# 276333    387.55
# 276334    454.91
# 276335    582.21
# Name: 청담대교_유량, Length: 276336, dtype: float64

# %%
nanIndex = 청담대교_유량[청담대교_유량.isnull()].index
nanIndex
# Out:
# Int64Index([269449, 269450, 269452, 269453, 269454, 269455, 269456, 269457,
#             269458, 269459,
#             ...
#             273770, 273771, 273772, 273773, 273774, 273775, 273776, 273777,
#             273778, 273779],
#            dtype='int64', length=1216)

# %%
unconsecutive = []
consecutive = []

i = 0
while i < len(nanIndex):
    if nanIndex[i]+1 in nanIndex: # 다음 거가 nanIndex 안에 있으면 다음 거까지 consecutive에 추가
        consecutive.extend([nanIndex[i], nanIndex[i+1]])
        try:
            i += 2
        except: #i가 len(nanIndex2) - 1
            break
    elif nanIndex[i]-1 in nanIndex: #다음 거는 nanIndex 안에 없지만 consecutive로 들어가야 하는 경우(반복 구간의 마지막 원소)
        consecutive.append(nanIndex[i])
        i += 1
    else:
        unconsecutive.append(nanIndex[i])
        i += 1

# %%
print(len(consecutive), len(unconsecutive))
# Out:
# 1203 13

# %%
# consecutive 내에서 구간별로 분리
dummy = []
consecutive2 = [] # 2차원 consecutive
for i in consecutive: 
    dummy.append(i)
    if i+1 not in consecutive:
        consecutive2.append(dummy)
        dummy= []

# %%
len(sum(consecutive2, [])) == len(consecutive)
# Out:
# True

# %%
# 2차원 consecutive의 모양 확인(길이, 첫index, 끝index)
for i in range(len(consecutive2)):
    print(len(consecutive2[i]), consecutive2[i][0], consecutive2[i][-1])
# Out:
# 2 269449 269450
# 12 269452 269463
# 2 269476 269477
# 20 269598 269617
# 13 269690 269702
# 4 269714 269717
# 7 269730 269736
# 20 269742 269761
# 2 269772 269773
# 4 269847 269850
# 6 269861 269866
# 29 269876 269904
# 11 269910 269920
# 12 269986 269997
# 7 270008 270014
# 48 270022 270069
# 104 270116 270219
# 115 270232 270346
# 23 270348 270370
# 6 270381 270386
# 88 270395 270482
# 9 270492 270500
# 3 270502 270504
# 12 270508 270519
# 5 270533 270537
# 76 270548 270623
# 8 270634 270641
# 20 270646 270665
# 2 270713 270714
# 42 270728 270769
# 7 270779 270785
# 29 270795 270823
# 10 270832 270841
# 13 270846 270858
# 38 270862 270899
# 3 270911 270913
# 13 270959 270971
# 65 270982 271046
# 10 271074 271083
# 33 271087 271119
# 2 271162 271163
# 3 271167 271169
# 2 271335 271336
# 9 271407 271415
# 4 272081 272084
# 9 272341 272349
# 6 272380 272385
# 20 272447 272466
# 11 272474 272484
# 3 272489 272491
# 5 272503 272507
# 6 272519 272524
# 6 272531 272536
# 12 272550 272561
# 55 272565 272619
# 8 272624 272631
# 109 273671 273779

# %% [markdown]
# ### 보간처리

# %%
# 보간처리를 위해 앞뒤 인덱스를 포함한 unconsecutive2 인덱스
unconsecutive2 = sum([[i-1, i, i+1] for i in unconsecutive], [])
# sum(list, []) : to unfold the list

# %%
# 겹치는 인덱스가 없는지 확인
len(unconsecutive2) == len(unconsecutive) * 3
# Out:
# True

# %%
청담대교_유량[unconsecutive2] = 청담대교_유량[unconsecutive2].interpolate()

# %%
청담대교_유량[unconsecutive2].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### CNN

# %%
# n: 학습할 데이터 개수, w: window size

n_list = [len(consecutive2[i]) for i in range(len(consecutive2))]
w = 6
print(len(n_list))
# Out:
# 57

# %%
# xtrain, ytrain 생성(모든 구간)
input = []
xtrain = []
ytrain = []
xtrain_tmp = []
ytrain_tmp = []

for i in tqdm(range(len(n_list))):
  # i번째 구간 train set을 위한 인덱스 설정
  n = n_list[i]
  end = consecutive2[i][0]
  input = 청담대교_유량[:end]

  # xtrain_tmp에 train용 input데이터를 넣은 후 xtrain에 또 넣기
  for j in range(len(input)-w-n-100000, len(input)-w-n):
    xtrain_tmp.append(np.array(input.iloc[j:j+w]).astype(float))
    xtrain.append(xtrain_tmp)
    xtrain_tmp = []

  # ytrain_tmp에 train용 output데이터를 넣은 후 ytrain에 또 넣기
  for k in range(len(input)-n-100000, len(input)-n):
    ytrain_tmp.append(np.array(input.iloc[k:k+n]).astype(float))
    ytrain.append(ytrain_tmp)
    ytrain_tmp = []

  # csv 파일로 저장 
  pd.DataFrame(xtrain[i]).to_csv(f'/content/drive/MyDrive/신입기수 프로젝트/Dataset/CNN_전처리/청담대교_유량/{i+1}th_idx', index = False, encoding = 'cp949')
# Out:
#  77%|███████▋  | 44/57 [05:34<01:38,  7.60s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-ae5ea633d193> in <module>
#      14   # xtrain_tmp에 train용 input데이터를 넣은 후 xtrain에 또 넣기
#      15   for j in range(len(input)-w-n-100000, len(input)-w-n):
# ---> 16     xtrain_tmp.append(np.array(input.iloc[j:j+w]).astype(float))
#      17     xtrain.append(xtrain_tmp)
#      18     xtrain_tmp = []
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1541
#    1542         if isinstance(key, slice):
# -> 1543             return self._get_slice_axis(key, axis=axis)
#    1544
#    1545         if is_iterator(key):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1577         labels = obj._get_axis(axis)
#    1578         labels._validate_positional_slice(slice_obj)
# -> 1579         return self.obj._slice(slice_obj, axis=axis)
#    1580
#    1581     def _convert_to_indexer(self, key, axis: int, is_setter: bool = False):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _slice(self, slobj, axis)
#     924         # axis kwarg is retained for compat with NDFrame method
#     925         #  _slice is *always* positional
# --> 926         return self._get_values(slobj)
#     927
#     928     def __getitem__(self, key):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _get_values(self, indexer)
#    1025         try:
#    1026             new_mgr = self._mgr.getitem_mgr(indexer)
# -> 1027             return self._constructor(new_mgr).__finalize__(self)
#    1028         except ValueError:
#    1029             # mpl compat if we look up e.g. ser[:, np.newaxis];
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __finalize__(self, other, method, **kwargs)
#    5459             self.flags.allows_duplicate_labels = other.flags.allows_duplicate_labels
#    5460             # For subclasses using _metadata.
# -> 5461             for name in set(self._metadata) & set(other._metadata):
#    5462                 assert isinstance(name, str)
#    5463                 object.__setattr__(self, name, getattr(other, name, None))
#
# KeyboardInterrupt:

# %%
consecutive2[0][0]
# Out:
# 269449

# %%
x_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-80784060c951> in <module>
# ----> 1 x_train
#
# NameError: name 'x_train' is not defined

# %%
청담대교_유량[:consecutive2[0][0]]
# Out:
# 0         469.05
# 1         498.00
# 2         490.68
# 3         476.21
# 4         476.21
#            ...
# 269444    258.79
# 269445    253.57
# 269446    253.57
# 269447    248.40
# 269448    243.29
# Name: 청담대교_유량, Length: 269449, dtype: float64

# %%
# 58개 결측치 앞 인덱스까지 인풋 생성
x = 수위.loc[:140612]

# 결측치로 아웃풋 생성
null = 수위[140613:140671]

# %%
null
# Out:
#         청담대교_수위  한강대교_수위  잠수교_수위  행주대교_수위
# 140613      NaN      NaN     NaN      NaN
# 140614      NaN      NaN     NaN      NaN
# 140615      NaN      NaN     NaN      NaN
# 140616      NaN      NaN     NaN      NaN
# 140617      NaN      NaN     NaN      NaN
# 140618      NaN      NaN     NaN      NaN
# 140619      NaN      NaN     NaN      NaN
# 140620      NaN      NaN     NaN      NaN
# 140621      NaN      NaN     NaN      NaN
# 140622      NaN      NaN     NaN      NaN
# 140623      NaN      NaN     NaN      NaN
# 140624      NaN      NaN     NaN      NaN
# 140625      NaN      NaN     NaN      NaN
# 140626      NaN      NaN     NaN      NaN
# 140627      NaN      NaN     NaN      NaN
# 140628      NaN      NaN     NaN      NaN
# 140629      NaN      NaN     NaN      NaN
# 140630      NaN      NaN     NaN      NaN
# 140631      NaN      NaN     NaN      NaN
# 140632      NaN      NaN     NaN      NaN
# 140633      NaN      NaN     NaN      NaN
# 140634      NaN      NaN     NaN      NaN
# 140635      NaN      NaN     NaN      NaN
# 140636      NaN      NaN     NaN      NaN
# 140637      NaN      NaN     NaN      NaN
# 140638      NaN      NaN     NaN      NaN
# 140639      NaN      NaN     NaN      NaN
# 140640      NaN      NaN     NaN      NaN
# 140641      NaN      NaN     NaN      NaN
# 140642      NaN      NaN     NaN      NaN
# 140643      NaN      NaN     NaN      NaN
# 140644      NaN      NaN     NaN      NaN
# 140645      NaN      NaN     NaN      NaN
# 140646      NaN      NaN     NaN      NaN
# 140647      NaN      NaN     NaN      NaN
# 140648      NaN      NaN     NaN      NaN
# 140649      NaN      NaN     NaN      NaN
# 140650      NaN      NaN     NaN      NaN
# 140651      NaN      NaN     NaN      NaN
# 140652      NaN      NaN     NaN      NaN
# 140653      NaN      NaN     NaN      NaN
# 140654      NaN      NaN     NaN      NaN
# 140655      NaN      NaN     NaN      NaN
# 140656      NaN      NaN     NaN      NaN
# 140657      NaN      NaN     NaN      NaN
# 140658      NaN      NaN     NaN      NaN
# 140659      NaN      NaN     NaN      NaN
# 140660      NaN      NaN     NaN      NaN
# 140661      NaN      NaN     NaN      NaN
# 140662      NaN      NaN     NaN      NaN
# 140663      NaN      NaN     NaN      NaN
# 140664      NaN      NaN     NaN      NaN
# 140665      NaN      NaN     NaN      NaN
# 140666      NaN      NaN     NaN      NaN
# 140667      NaN      NaN     NaN      NaN
# 140668      NaN      NaN     NaN      NaN
# 140669      NaN      NaN     NaN      NaN
# 140670      NaN      NaN     NaN      NaN

# %%
x
# Out:
#         청담대교_수위  한강대교_수위  잠수교_수위  행주대교_수위
# 0         310.7    290.0   300.2    275.3
# 1         314.7    290.0   300.2    275.3
# 2         313.7    290.0   301.2    275.3
# 3         311.7    290.0   301.2    276.3
# 4         311.7    291.0   301.2    277.3
# ...         ...      ...     ...      ...
# 140608    435.7    410.0   415.2    374.3
# 140609    438.7    413.0   418.2    375.3
# 140610    437.7    413.0   418.2    373.3
# 140611    434.7    413.0   415.2    373.3
# 140612    429.7    410.0   412.2    375.3
#
# [140613 rows x 4 columns]

# %%
# conda install scikit-learn

# %%
# train, test data 생성할 때 필요
from sklearn.model_selection import train_test_split
# 정규화할 때 필요
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
# input 정규화
x_regular = x.copy()

for i in range(len(x.columns)):
    scaler = StandardScaler()                       #StandardScaler() , MinMaxScaler() , RobustScaler()
    a=np.array(x_regular.iloc[:,i])
    tmp_x = scaler.fit_transform(a.reshape(-1,1))
    x_regular.iloc[:,i] = tmp_x

# %%
x_regular
# Out:
#          청담대교_수위   한강대교_수위    잠수교_수위   행주대교_수위
# 0      -0.213183 -0.292141 -0.168958 -0.473340
# 1      -0.150481 -0.292141 -0.168958 -0.473340
# 2      -0.166156 -0.292141 -0.151149 -0.473340
# 3      -0.197507 -0.292141 -0.151149 -0.450834
# 4      -0.197507 -0.273710 -0.151149 -0.428328
# ...          ...       ...       ...       ...
# 140608  1.746252  1.919546  1.879052  1.754767
# 140609  1.793278  1.974838  1.932478  1.777274
# 140610  1.777603  1.974838  1.932478  1.732261
# 140611  1.730576  1.974838  1.879052  1.732261
# 140612  1.652199  1.919546  1.825626  1.777274
#
# [140613 rows x 4 columns]

# %% [markdown]
# ### 청담대교 수위

# %%
start = time.time()

y_predict = []

xtrain = []
ytrain = []

w =  432 # window size
n = 58 # 예측할 데이터 개수

# xtrain 생성
# for i in range(len(x_regular)-w):
#     xtrain.append(np.array(x_regular.iloc[i:i + w, :]).astype(float))

for i in tqdm(range(len(x_regular)-w-n)):
    xtrain.append(np.array(x_regular.iloc[i:i + w, 0]).astype(float))
# Out:
# 100%|██████████| 140123/140123 [00:17<00:00, 8088.92it/s]

# %%
# ytrain 생성
# for i in range(w, len(x_regular)):
#     ytrain.append(np.array(x_regular.iloc[i, :]).astype(float))
ytrain = []

for i in tqdm(range(w, len(x_regular)-n)):
  ytrain.append(np.array(x_regular.iloc[i:i+n, 0]).astype(float))
# Out:
# 100%|██████████| 140123/140123 [00:14<00:00, 9594.30it/s]

# %%
xtrain = np.array(xtrain)
ytrain = np.array(ytrain)
print(xtrain.shape)
print(ytrain.shape)
# Out:
# (140123, 432)
# (140123, 58)

# %%
df_xtrain = pd.DataFrame(xtrain, columns = [i for i in range(432)])

# %%
df_ytrain = pd.DataFrame(ytrain, columns = [f'R{i}' for i in range(58)])

# %%
df_series = pd.concat([df_xtrain, df_ytrain], axis = 1)

# %%
df_series.shape
# Out:
# (140123, 490)

# %%
xtrain.reshape(140123, 432, 1)
ytrain.reshape(140123, 58, 1)
# Out:
# array([[[-0.30723539],
#         [-0.27588445],
#         [-0.32291086],
#         ...,
#         [-0.18183161],
#         [-0.15048066],
#         [-0.15048066]],
#
#        [[-0.27588445],
#         [-0.32291086],
#         [-0.30723539],
#         ...,
#         [-0.15048066],
#         [-0.15048066],
#         [-0.15048066]],
#
#        [[-0.32291086],
#         [-0.30723539],
#         [-0.36993728],
#         ...,
#         [-0.15048066],
#         [-0.15048066],
#         [-0.10345424]],
#
#        ...,
#
#        [[ 0.05330049],
#         [ 0.02194954],
#         [-0.02507688],
#         ...,
#         [ 1.68354968],
#         [ 1.74625158],
#         [ 1.79327799]],
#
#        [[ 0.02194954],
#         [-0.02507688],
#         [-0.0721033 ],
#         ...,
#         [ 1.74625158],
#         [ 1.79327799],
#         [ 1.77760252]],
#
#        [[-0.02507688],
#         [-0.0721033 ],
#         [-0.10345424],
#         ...,
#         [ 1.79327799],
#         [ 1.77760252],
#         [ 1.7305761 ]]])

# %%
# label
labels_col = [f'R{i}' for i in range(58)]
labels = df_series[labels_col]
series = df_series.drop(labels_col, axis=1)
labels.values.shape
# Out:
# (140123, 58)

# %%
# x_train, x_val, y_train, y_val 분류
x_train, x_val, y_train, y_val = train_test_split(series, labels.values, test_size = 0.4, random_state = 0)

# %%
x_train
# Out:
#              0         1         2         3         4         5         6    \
# 133922 -0.354262 -0.354262 -0.369937 -0.385613 -0.432639 -0.463990 -0.479666
# 32870  -0.495341 -0.511017 -0.526692 -0.526692 -0.542367 -0.542367 -0.558043
# 53652  -0.291560 -0.354262 -0.448315 -0.511017 -0.495341 -0.463990 -0.432639
# 2311   -0.542367 -0.542367 -0.542367 -0.542367 -0.542367 -0.526692 -0.511017
# 132218 -0.636420 -0.620745 -0.620745 -0.620745 -0.636420 -0.652096 -0.652096
# ...          ...       ...       ...       ...       ...       ...       ...
# 41993  -0.009401  0.006274  0.006274  0.021950  0.021950  0.037625  0.037625
# 97639   1.150584  1.072206  0.962478  0.852750  0.727346  0.586267  0.476538
# 95939  -0.699122 -0.714798 -0.730473 -0.730473 -0.730473 -0.714798 -0.699122
# 117952  0.335459  0.319784  0.304108  0.288433  0.257082  0.257082  0.225731
# 43567   0.476538  0.413836  0.288433  0.147353  0.053300 -0.040752 -0.072103
#
#              7         8         9    ...       422       423       424  \
# 133922 -0.511017 -0.526692 -0.526692  ...  0.037625  0.100327  0.131678
# 32870  -0.558043 -0.558043 -0.558043  ... -0.558043 -0.558043 -0.558043
# 53652  -0.416964 -0.385613 -0.369937  ... -0.761824 -0.730473 -0.730473
# 2311   -0.526692 -0.542367 -0.526692  ... -0.385613 -0.401288 -0.385613
# 132218 -0.652096 -0.667771 -0.683447  ... -0.558043 -0.589394 -0.589394
# ...          ...       ...       ...  ...       ...       ...       ...
# 41993   0.037625  0.037625  0.037625  ...  0.257082  0.225731  0.147353
# 97639   0.429512  0.398161  0.366810  ... -0.871552 -0.887228 -0.871552
# 95939  -0.683447 -0.699122 -0.683447  ... -0.840201 -0.855877 -0.855877
# 117952  0.225731  0.194380  0.178704  ...  1.134908  1.150584  1.134908
# 43567  -0.072103 -0.072103 -0.025077  ...  0.006274  0.006274 -0.009401
#
#              425       426       427       428       429       430       431
# 133922  0.131678  0.116002  0.084651  0.053300 -0.025077 -0.087779 -0.181832
# 32870  -0.558043 -0.573718 -0.573718 -0.589394 -0.605069 -0.605069 -0.605069
# 53652  -0.714798 -0.746149 -0.730473 -0.746149 -0.730473 -0.746149 -0.730473
# 2311   -0.401288 -0.416964 -0.432639 -0.495341 -0.495341 -0.511017 -0.511017
# 132218 -0.573718 -0.542367 -0.526692 -0.511017 -0.511017 -0.511017 -0.526692
# ...          ...       ...       ...       ...       ...       ...       ...
# 41993   0.147353  0.084651  0.084651  0.068976  0.006274  0.021950  0.006274
# 97639  -0.871552 -0.871552 -0.871552 -0.871552 -0.871552 -0.871552 -0.871552
# 95939  -0.871552 -0.855877 -0.855877 -0.855877 -0.840201 -0.808851 -0.746149
# 117952  1.119233  1.056531  0.978153  0.868425  0.774372  0.680319  0.617618
# 43567   0.006274  0.021950  0.037625  0.037625  0.037625  0.053300  0.037625
#
# [84073 rows x 432 columns]

# %%
# xtest =

# %%
# 모델링 및 모델 학습

if 'model' in locals(): 
    del model 
if 'history' in locals():
    del history


#He_normal
He_normal = keras.initializers.he_normal(seed=None)

model = Sequential()
model.add(Conv1D(filters = 8, input_shape = (w, 1), kernel_size = 2, padding='causal', dilation_rate=2, kernel_initializer = He_normal))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))  #0.2~0.5  0.8까지

model.add(Conv1D(filters = 16, kernel_size = 2, padding='causal', dilation_rate=4, kernel_initializer = He_normal))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Conv1D(filters = 32, kernel_size = 1))

model.add(Flatten())   #model.add(GlobalAveragePooling1D(pool_size=2))

model.add(Dense(50, kernel_initializer = He_normal))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Dense(58))


def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true))) 

opt = tf.keras.optimizers.Adam(lr=0.005) #기본값 0.001
model.compile(optimizer=opt, loss=root_mean_squared_error, metrics =["accuracy"])
model.summary()



callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss',
                                            patience=5),
                keras.callbacks.ModelCheckpoint(filepath='best_model.h5',
                                                monitor='val_loss',
                                                save_best_only=True)]



history = model.fit(xtrain, ytrain, epochs=300, validation_data = (x_val, y_val), verbose=1, callbacks=callbacks, batch_size = 3742) #batch size..?


keras_model_best = keras.models.load_model('best_model.h5', custom_objects={'root_mean_squared_error': root_mean_squared_error})

keras_model_best.evaluate(x_val,y_val)

# y_predict.append(keras_model_best.predict(xtest))

print("time :", time.time() - start, "초")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 432, 8)            24
#
#  batch_normalization (BatchN  (None, 432, 8)           32
#  ormalization)
#
#  activation (Activation)     (None, 432, 8)            0
#
#  dropout (Dropout)           (None, 432, 8)            0
#
#  conv1d_1 (Conv1D)           (None, 432, 16)           272
#
#  batch_normalization_1 (Batc  (None, 432, 16)          64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 432, 16)           0
#
#  dropout_1 (Dropout)         (None, 432, 16)           0
#
#  conv1d_2 (Conv1D)           (None, 432, 32)           544
#
#  flatten (Flatten)           (None, 13824)             0
#
#  dense (Dense)               (None, 50)                691250
#
#  batch_normalization_2 (Batc  (None, 50)               200
#  hNormalization)
#
#  activation_2 (Activation)   (None, 50)                0
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense_1 (Dense)             (None, 58)                2958
#
# =================================================================
# Total params: 695,344
# Trainable params: 695,196
# Non-trainable params: 148
# _________________________________________________________________
# Epoch 1/300
# 38/38 [==============================] - 99s 3s/step - loss: 0.6876 - accuracy: 0.0293 - val_loss: 1.0564 - val_accuracy: 0.0466
# Epoch 2/300
# 38/38 [==============================] - 97s 3s/step - loss: 0.4393 - accuracy: 0.0784 - val_loss: 0.7516 - val_accuracy: 0.1087
# Epoch 3/300
# 38/38 [==============================] - 99s 3s/step - loss: 0.3802 - accuracy: 0.1325 - val_loss: 0.5935 - val_accuracy: 0.1499
# Epoch 4/300
# 38/38 [==============================] - 93s 2s/step - loss: 0.3607 - accuracy: 0.1672 - val_loss: 0.4594 - val_accuracy: 0.2008
# Epoch 5/300
# 38/38 [==============================] - 101s 3s/step - loss: 0.3500 - accuracy: 0.1954 - val_loss: 0.4835 - val_accuracy: 0.2218
# Epoch 6/300
# 38/38 [==============================] - 96s 3s/step - loss: 0.3362 - accuracy: 0.2142 - val_loss: 0.3211 - val_accuracy: 0.2565
# Epoch 7/300
# 38/38 [==============================] - 101s 3s/step - loss: 0.3314 - accuracy: 0.2278 - val_loss: 0.4103 - val_accuracy: 0.2231
# Epoch 8/300
# 38/38 [==============================] - 98s 3s/step - loss: 0.3278 - accuracy: 0.2383 - val_loss: 0.4382 - val_accuracy: 0.2549
# Epoch 9/300
# 38/38 [==============================] - 98s 3s/step - loss: 0.3217 - accuracy: 0.2500 - val_loss: 0.5560 - val_accuracy: 0.2386
# Epoch 10/300
# 38/38 [==============================] - 100s 3s/step - loss: 0.3155 - accuracy: 0.2609 - val_loss: 0.5131 - val_accuracy: 0.2728
# Epoch 11/300
# 38/38 [==============================] - 102s 3s/step - loss: 0.3112 - accuracy: 0.2660 - val_loss: 0.5808 - val_accuracy: 0.2830
# 1752/1752 [==============================] - 19s 10ms/step - loss: 0.3041 - accuracy: 0.2565
# time : 1159.335011959076 초

# %%
x_test = x['청담대교_수위'][-432:]

# %%
x_test = x_test.reshape((1, 432, 1))

# %%
x_test.shape
# Out:
# (1, 432, 1)

# %%
y_predict = keras_model_best.predict(x_test)

# %%
y_predict.shape
# Out:
# (1, 58)

# %%
pd.Series(list(y_predict))
# Out:
# 0    [356.7141, 353.11176, 363.21722, 363.84454, 36...
# dtype: object

# %%
수위.loc[consecutive, '청담대교_수위'] = y_predict

# %%
수위.loc[consecutive, '청담대교_수위']
# Out:
# 140613    356.714111
# 140614    353.111755
# 140615    363.217224
# 140616    363.844543
# 140617    365.909119
# 140618    363.827393
# 140619    364.425659
# 140620    364.011261
# 140621    363.490387
# 140622    364.510864
# 140623    364.045715
# 140624    363.996552
# 140625    361.002045
# 140626    359.652863
# 140627    360.933014
# 140628    355.186127
# 140629    353.749451
# 140630    354.733490
# 140631    350.926605
# 140632    350.105225
# 140633    347.467255
# 140634    344.468597
# 140635    343.386444
# 140636    339.775391
# 140637    336.228516
# 140638    329.561920
# 140639    326.070129
# 140640    325.695068
# 140641    318.948090
# 140642    316.603027
# 140643    314.934814
# 140644    311.850098
# 140645    311.948181
# 140646    312.573517
# 140647    310.761322
# 140648    313.600708
# 140649    314.994293
# 140650    315.581421
# 140651    317.602631
# 140652    321.123718
# 140653    321.627136
# 140654    323.130249
# 140655    320.198242
# 140656    324.375580
# 140657    324.597595
# 140658    325.360321
# 140659    323.838043
# 140660    324.523712
# 140661    320.275299
# 140662    320.290070
# 140663    319.149200
# 140664    316.453003
# 140665    314.247772
# 140666    313.217590
# 140667    312.359314
# 140668    313.722137
# 140669    310.624817
# 140670    309.308197
# Name: 청담대교_수위, dtype: float64

# %%
# unconsecutive 부분 보간

unconsecutive2 = [unconsecutive-1, unconsecutive, unconsecutive+1]
수위.loc[unconsecutive2, '청담대교_수위'] = 수위.loc[unconsecutive2, '청담대교_수위'].interpolate()

# %%
수위['청담대교_수위'].isnull().sum()
# Out:
# 0

# %%
수위['청담대교_수위'].to_csv('/content/drive/MyDrive/신입기수 프로젝트/Dataset/CNN_전처리/청담대교_수위.csv', index = False, encoding = 'cp949')
