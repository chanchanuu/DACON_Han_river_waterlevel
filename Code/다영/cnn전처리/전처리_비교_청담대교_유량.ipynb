# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Activation, Dense, LSTM, GRU, AveragePooling1D, GlobalAveragePooling1D, Dropout, Flatten, BatchNormalization
from keras.layers.convolutional import Conv1D, MaxPooling1D, AveragePooling1D 
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import backend as K

# %% [markdown]
# ### 행주대교_유량

# %%
행주대교_유량 = pd.read_csv('/content/drive/MyDrive/신입기수 프로젝트/Dataset/newdata.csv', encoding = 'cp949')
행주대교_유량 = 행주대교_유량['행주대교_유량']
행주대교_유량
# Out:
# 0          540.18
# 1          540.18
# 2          540.18
# 3          552.17
# 4          564.29
#            ...
# 276331     974.40
# 276332    1006.88
# 276333    1039.90
# 276334    1073.46
# 276335    1090.45
# Name: 행주대교_유량, Length: 276336, dtype: float64

# %% [markdown]
# ### 한강대교_유량

# %%
행주대교_유량 = pd.read_csv('/content/drive/MyDrive/신입기수 프로젝트/Dataset/newdata.csv', encoding = 'cp949')
한강대교_유량 = 행주대교_유량['한강대교_유량']

# %%
한강대교_유량
# Out:
# 0          729.80
# 1          731.48
# 2          726.42
# 3          726.42
# 4          707.17
#            ...
# 276331    -456.41
# 276332    -717.30
# 276333    -843.37
# 276334   -1023.37
# 276335   -1049.44
# Name: 한강대교_유량, Length: 276336, dtype: float64

# %% [markdown]
# ### 청담대교_유량_CNN

# %%
청담대교_유량_CNN = pd.read_csv('/content/drive/MyDrive/신입기수 프로젝트/Dataset/newdata3.csv', encoding = 'cp949')
청담대교_유량_CNN = 청담대교_유량_CNN['청담대교_유량']

# %%
청담대교_유량_CNN
# Out:
# 0         469.05
# 1         498.00
# 2         490.68
# 3         476.21
# 4         476.21
#            ...
# 276332    314.01
# 276333    387.55
# 276334    454.91
# 276335    582.21
# 276336       NaN
# Name: 청담대교_유량, Length: 276337, dtype: float64

# %% [markdown]
# ### 시각화

# %%
# 연속적인 결측치 구간
consecutive = list(range(140613, 140671))
consecutive
# Out:
# [140613,
#  140614,
#  140615,
#  140616,
#  140617,
#  140618,
#  140619,
#  140620,
#  140621,
#  140622,
#  140623,
#  140624,
#  140625,
#  140626,
#  140627,
#  140628,
#  140629,
#  140630,
#  140631,
#  140632,
#  140633,
#  140634,
#  140635,
#  140636,
#  140637,
#  140638,
#  140639,
#  140640,
#  140641,
#  140642,
#  140643,
#  140644,
#  140645,
#  140646,
#  140647,
#  140648,
#  140649,
#  140650,
#  140651,
#  140652,
#  140653,
#  140654,
#  140655,
#  140656,
#  140657,
#  140658,
#  140659,
#  140660,
#  140661,
#  140662,
#  140663,
#  140664,
#  140665,
#  140666,
#  140667,
#  140668,
#  140669,
#  140670]

# %%
col = [행주대교_유량, 한강대교_유량, 청담대교_유량_CNN]

start = 273671-100
end = 273779+100
x = range(len(한강대교_유량.loc[start:end]))
fig = plt.figure(figsize = (12, 8))

y1 = 행주대교_유량.loc[start:end]
y2 = 한강대교_유량.loc[start:end]
y3 = 청담대교_유량_CNN.loc[start:end]

ax = fig.add_subplot(1, 1, 1)
ax.plot(x, y1, color = 'orange', label = '행주대교')
ax.plot(x, y2, color = 'skyblue', label = '한강대교_유량')
ax.plot(x, y3, color = 'green', label = '청담대교_유량_CNN')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
