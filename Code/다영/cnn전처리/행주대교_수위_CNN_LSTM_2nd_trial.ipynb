# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings(action='ignore')

import time
from glob import glob
from tqdm import tqdm

import tensorflow as tf
import tensorflow.keras as keras
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras import backend as K
# from keras.utils import plot_model

from keras.layers import Activation, Dense, LSTM, GRU, Bidirectional, AveragePooling1D, GlobalAveragePooling1D, Dropout, Flatten, BatchNormalization, TimeDistributed, Input, Reshape, RepeatVector, Concatenate, GlobalMaxPooling1D 
from keras.layers.convolutional import Conv1D, MaxPooling1D, AveragePooling1D


#GPU 자원이 부족
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
raw_data = pd.read_csv('/content/drive/MyDrive/신입기수 프로젝트/Dataset/rawdata.csv')

# %%
raw_data
# Out:
#                       날짜    현재수위     유입량     저수량    공용량     방류량  강화대교_조위  \
# 0       2012-05-01 00:00  24.800  555.00  219.07  24.93  555.00    445.0
# 1       2012-05-01 00:10  24.794  464.60  218.86  25.15  562.90    449.0
# 2       2012-05-01 00:20  24.789  478.10  218.69  25.31  576.40    451.0
# 3       2012-05-01 00:30  24.789  464.80  218.69  25.31  563.10    452.0
# 4       2012-05-01 00:40  24.789  478.10  218.69  25.31  576.40    450.0
# ...                  ...     ...     ...     ...    ...     ...      ...
# 276331  2022-07-18 23:10  25.040  259.23  212.86  31.14  259.23    510.0
# 276332  2022-07-18 23:20  25.040  260.46  212.86  31.14  260.46    492.0
# 276333  2022-07-18 23:30  25.040  259.37  212.86  31.14  259.37    475.0
# 276334  2022-07-18 23:40  25.040  259.13  212.86  31.14  259.13    458.0
# 276335  2022-07-18 23:50  25.040  258.16  212.86  31.14  258.16    442.0
#
#         청담대교_유량  잠수교_유량  한강대교_유량  행주대교_유량  대곡교_강수량  진관교_강수량  송정동_강수량  청담대교_수위  \
# 0        469.05     0.0   729.80   540.18      0.0      0.0      0.0    310.7
# 1        498.00     0.0   731.48   540.18      0.0      0.0      0.0    314.7
# 2        490.68     0.0   726.42   540.18      0.0      0.0      0.0    313.7
# 3        476.21     0.0   726.42   552.17      0.0      0.0      0.0    311.7
# 4        476.21     0.0   707.17   564.29      0.0      0.0      0.0    311.7
# ...         ...     ...      ...      ...      ...      ...      ...      ...
# 276331   319.84     NaN  -456.41   974.40      0.0      0.0      0.0      0.0
# 276332   314.01     NaN  -717.30  1006.88      0.0      0.0      0.0      0.0
# 276333   387.55     NaN  -843.37  1039.90      0.0      0.0      0.0      0.0
# 276334   454.91     NaN -1023.37  1073.46      0.0      0.0      0.0      0.0
# 276335   582.21     NaN -1049.44  1090.45      0.0      0.0      0.0      0.0
#
#         잠수교_수위  한강대교_수위  행주대교_수위
# 0        300.2    290.0    275.3
# 1        300.2    290.0    275.3
# 2        301.2    290.0    275.3
# 3        301.2    290.0    276.3
# 4        301.2    291.0    277.3
# ...        ...      ...      ...
# 276331     0.0      0.0      0.0
# 276332     0.0      0.0      0.0
# 276333     0.0      0.0      0.0
# 276334     0.0      0.0      0.0
# 276335     0.0      0.0      0.0
#
# [276336 rows x 18 columns]

# %%
raw_data = raw_data['행주대교_수위']

# %%
nanIndex = raw_data[raw_data.isnull()==True].index

# %%
nanIndex
# Out:
# Int64Index([140613, 140614, 140615, 140616, 140617, 140618, 140619, 140620,
#             140621, 140622, 140623, 140624, 140625, 140626, 140627, 140628,
#             140629, 140630, 140631, 140632, 140633, 140634, 140635, 140636,
#             140637, 140638, 140639, 140640, 140641, 140642, 140643, 140644,
#             140645, 140646, 140647, 140648, 140649, 140650, 140651, 140652,
#             140653, 140654, 140655, 140656, 140657, 140658, 140659, 140660,
#             140661, 140662, 140663, 140664, 140665, 140666, 140667, 140668,
#             140669, 140670, 236080],
#            dtype='int64')

# %%
consecutive = list(nanIndex)[:-1]
unconsecutive = list(nanIndex)[-1]
print(consecutive)
print(unconsecutive)
# Out:
# [140613, 140614, 140615, 140616, 140617, 140618, 140619, 140620, 140621, 140622, 140623, 140624, 140625, 140626, 140627, 140628, 140629, 140630, 140631, 140632, 140633, 140634, 140635, 140636, 140637, 140638, 140639, 140640, 140641, 140642, 140643, 140644, 140645, 140646, 140647, 140648, 140649, 140650, 140651, 140652, 140653, 140654, 140655, 140656, 140657, 140658, 140659, 140660, 140661, 140662, 140663, 140664, 140665, 140666, 140667, 140668, 140669, 140670]
# 236080

# %%
print(len(consecutive) + 1 == len(nanIndex) )
# Out:
# True

# %%
# 58개 결측치 앞 인덱스까지 인풋 생성
x = raw_data.iloc[:140613]

# %%
x
# Out:
# 0         275.3
# 1         275.3
# 2         275.3
# 3         276.3
# 4         277.3
#           ...
# 140608    374.3
# 140609    375.3
# 140610    373.3
# 140611    373.3
# 140612    375.3
# Name: 행주대교_수위, Length: 140613, dtype: float64

# %%
y_predict = []

xtrain = []
ytrain = []

w =  200 # window size
n = 58 # 예측할 데이터 개수

for i in tqdm(range(len(x)-w-n)):
    xtrain.append(np.array(x.iloc[i:i + w]).astype(float))
for i in tqdm(range(w, len(x)-n)):
  ytrain.append(np.array(x.iloc[i:i+n]).astype(float))
# Out:
# 100%|██████████| 140355/140355 [00:05<00:00, 24268.62it/s]
# 100%|██████████| 140355/140355 [00:05<00:00, 23833.98it/s]

# %%
xtrain = np.array(xtrain).reshape(140355, 200, 1)
ytrain = np.array(ytrain).reshape(140355, 58,)

# %%
def inverse_transform(y_test, yhat):
     y_test_reshaped = y_test.reshape(-1, y_test.shape[-1])
     yhat_reshaped = yhat.reshape(-1, yhat.shape[-1])
     yhat_inverse = scaler.inverse_transform(yhat_reshaped)
     y_test_inverse = scaler.inverse_transform(y_test_reshaped)
     return yhat_inverse, y_test_inverse

def evaluate_forecast(y_test_inverse, yhat_inverse):
    mse_ = tf.keras.losses.MeanSquaredError()
    mae_ = tf.keras.losses.MeanAbsoluteError()
    mape_ = tf.keras.losses.MeanAbsolutePercentageError()
    rmse = np.sqrt(mae_(y_test_inverse,yhat_inverse))
    print('rmse:', rmse)
    mse = mse_(y_test_inverse,yhat_inverse)
    print('mse:', mse)
    mape = mape_(y_test_inverse,yhat_inverse)
    print('mape:', mape)

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true))) 

optimizer = tf.keras.optimizers.Adam(lr=0.01) #기본값 0.001

# %%
model_enc_dec_cnn = Sequential()
model_enc_dec_cnn.add(Conv1D(filters=8, kernel_size=2, activation='relu', input_shape=(w, xtrain.shape[2])))
model_enc_dec_cnn.add(Conv1D(filters=16, kernel_size=2, activation='relu'))
model_enc_dec_cnn.add(AveragePooling1D(pool_size=2))
model_enc_dec_cnn.add(Flatten())

model_enc_dec_cnn.add(RepeatVector(1))
model_enc_dec_cnn.add(LSTM(100, activation='relu', return_sequences=True))
model_enc_dec_cnn.add(LSTM(100, activation='relu'))

model_enc_dec_cnn.add(Dense(100, activation='relu'))
model_enc_dec_cnn.add(Dense(58))

model_enc_dec_cnn.compile(loss=root_mean_squared_error, optimizer=optimizer, metrics =["accuracy"])

# %%
model_enc_dec_cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 199, 8)            24
#
#  conv1d_3 (Conv1D)           (None, 198, 16)           272
#
#  average_pooling1d_1 (Averag  (None, 99, 16)           0
#  ePooling1D)
#
#  flatten_1 (Flatten)         (None, 1584)              0
#
#  repeat_vector_1 (RepeatVect  (None, 1, 1584)          0
#  or)
#
#  lstm_2 (LSTM)               (None, 1, 100)            674000
#
#  lstm_3 (LSTM)               (None, 100)               80400
#
#  dense (Dense)               (None, 100)               10100
#
#  dense_1 (Dense)             (None, 58)                5858
#
# =================================================================
# Total params: 770,654
# Trainable params: 770,654
# Non-trainable params: 0
# _________________________________________________________________

# %%
# plot_model(model=model_enc_dec_cnn, show_shapes=True)

# %%
epochs = 100
batch_size = 256
validation = 0.2

checkpoint_callback = ModelCheckpoint(filepath='best_model.h5', save_weights_only=False, monitor='val_loss',
                                         mode='min', save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', min_delta=0.005, patience=10, mode='min')
rlrop_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, mode='min', patience=3, min_lr=0.001)

history = model_enc_dec_cnn.fit(xtrain, ytrain, verbose=1, epochs=epochs, batch_size=batch_size, validation_split=validation,callbacks=[early_stopping_callback, checkpoint_callback, rlrop_callback])
# Out:
# Epoch 1/100
# 439/439 [==============================] - 32s 66ms/step - loss: 29.9012 - accuracy: 0.0270 - val_loss: 23.6007 - val_accuracy: 0.0244 - lr: 0.0100
# Epoch 2/100
# 439/439 [==============================] - 31s 70ms/step - loss: 22.6227 - accuracy: 0.0622 - val_loss: 19.7948 - val_accuracy: 0.0210 - lr: 0.0100
# Epoch 3/100
# 439/439 [==============================] - 27s 61ms/step - loss: 19.4753 - accuracy: 0.0654 - val_loss: 16.4748 - val_accuracy: 0.0556 - lr: 0.0100
# Epoch 4/100
# 439/439 [==============================] - 29s 67ms/step - loss: 18.2448 - accuracy: 0.0729 - val_loss: 14.9760 - val_accuracy: 0.0622 - lr: 0.0100
# Epoch 5/100
# 439/439 [==============================] - 27s 62ms/step - loss: 17.7415 - accuracy: 0.0658 - val_loss: 13.0492 - val_accuracy: 0.0501 - lr: 0.0100
# Epoch 6/100
# 439/439 [==============================] - 27s 61ms/step - loss: 17.0354 - accuracy: 0.0847 - val_loss: 12.6172 - val_accuracy: 0.0579 - lr: 0.0100
# Epoch 7/100
# 439/439 [==============================] - 28s 63ms/step - loss: 16.6163 - accuracy: 0.0890 - val_loss: 12.1564 - val_accuracy: 0.0630 - lr: 0.0100
# Epoch 8/100
# 439/439 [==============================] - 26s 60ms/step - loss: 16.1546 - accuracy: 0.0853 - val_loss: 11.2130 - val_accuracy: 0.0862 - lr: 0.0100
# Epoch 9/100
# 439/439 [==============================] - 26s 60ms/step - loss: 15.6123 - accuracy: 0.0820 - val_loss: 12.2098 - val_accuracy: 0.0568 - lr: 0.0100
# Epoch 10/100
# 439/439 [==============================] - 28s 63ms/step - loss: 15.3378 - accuracy: 0.0811 - val_loss: 11.7120 - val_accuracy: 0.0663 - lr: 0.0100
# Epoch 11/100
# 439/439 [==============================] - 26s 60ms/step - loss: 15.9155 - accuracy: 0.0873 - val_loss: 12.5156 - val_accuracy: 0.0815 - lr: 0.0100
# Epoch 12/100
# 439/439 [==============================] - 26s 60ms/step - loss: 14.1623 - accuracy: 0.0869 - val_loss: 11.7913 - val_accuracy: 0.0648 - lr: 0.0050
# Epoch 13/100
# 439/439 [==============================] - 26s 60ms/step - loss: 13.9129 - accuracy: 0.0880 - val_loss: 11.1431 - val_accuracy: 0.0636 - lr: 0.0050
# Epoch 14/100
# 439/439 [==============================] - 27s 61ms/step - loss: 13.9054 - accuracy: 0.0886 - val_loss: 10.6978 - val_accuracy: 0.0826 - lr: 0.0050
# Epoch 15/100
# 439/439 [==============================] - 27s 61ms/step - loss: 15.0026 - accuracy: 0.0862 - val_loss: 12.8795 - val_accuracy: 0.0971 - lr: 0.0050
# Epoch 16/100
# 439/439 [==============================] - 28s 63ms/step - loss: 13.8319 - accuracy: 0.0959 - val_loss: 12.0458 - val_accuracy: 0.0947 - lr: 0.0050
# Epoch 17/100
# 439/439 [==============================] - 26s 60ms/step - loss: 13.7743 - accuracy: 0.0961 - val_loss: 11.2213 - val_accuracy: 0.0738 - lr: 0.0050
# Epoch 18/100
# 439/439 [==============================] - 26s 60ms/step - loss: 13.1829 - accuracy: 0.0964 - val_loss: 11.3285 - val_accuracy: 0.0779 - lr: 0.0025
# Epoch 19/100
# 439/439 [==============================] - 26s 60ms/step - loss: 13.1992 - accuracy: 0.0944 - val_loss: 11.2370 - val_accuracy: 0.0735 - lr: 0.0025
# Epoch 20/100
# 439/439 [==============================] - 26s 60ms/step - loss: 13.2419 - accuracy: 0.0937 - val_loss: 10.7498 - val_accuracy: 0.0870 - lr: 0.0025
# Epoch 21/100
# 439/439 [==============================] - 26s 60ms/step - loss: 12.9712 - accuracy: 0.0950 - val_loss: 10.7853 - val_accuracy: 0.0869 - lr: 0.0012
# Epoch 22/100
# 439/439 [==============================] - 26s 60ms/step - loss: 12.9421 - accuracy: 0.0949 - val_loss: 10.5166 - val_accuracy: 0.0871 - lr: 0.0012
# Epoch 23/100
# 439/439 [==============================] - 28s 64ms/step - loss: 12.9712 - accuracy: 0.0964 - val_loss: 10.5700 - val_accuracy: 0.0898 - lr: 0.0012
# Epoch 24/100
# 439/439 [==============================] - 26s 60ms/step - loss: 12.9646 - accuracy: 0.0971 - val_loss: 10.9273 - val_accuracy: 0.0864 - lr: 0.0012
# Epoch 25/100
# 439/439 [==============================] - 26s 60ms/step - loss: 12.9457 - accuracy: 0.0998 - val_loss: 10.9481 - val_accuracy: 0.0898 - lr: 0.0012
# Epoch 26/100
# 439/439 [==============================] - 26s 60ms/step - loss: 12.8819 - accuracy: 0.1006 - val_loss: 10.4938 - val_accuracy: 0.0906 - lr: 0.0010
# Epoch 27/100
# 439/439 [==============================] - 26s 60ms/step - loss: 12.8846 - accuracy: 0.1032 - val_loss: 10.5293 - val_accuracy: 0.1018 - lr: 0.0010
# Epoch 28/100
# 439/439 [==============================] - 26s 60ms/step - loss: 12.8647 - accuracy: 0.1033 - val_loss: 10.4953 - val_accuracy: 0.0967 - lr: 0.0010
# Epoch 29/100
# 439/439 [==============================] - 28s 63ms/step - loss: 12.8494 - accuracy: 0.1059 - val_loss: 10.6993 - val_accuracy: 0.0977 - lr: 0.0010
# Epoch 30/100
# 439/439 [==============================] - 27s 61ms/step - loss: 12.7820 - accuracy: 0.1081 - val_loss: 10.4157 - val_accuracy: 0.1043 - lr: 0.0010
# Epoch 31/100
# 439/439 [==============================] - 27s 61ms/step - loss: 12.7720 - accuracy: 0.1099 - val_loss: 10.3176 - val_accuracy: 0.1047 - lr: 0.0010
# Epoch 32/100
# 439/439 [==============================] - 27s 61ms/step - loss: 12.7368 - accuracy: 0.1087 - val_loss: 10.4717 - val_accuracy: 0.1078 - lr: 0.0010
# Epoch 33/100
# 439/439 [==============================] - 27s 61ms/step - loss: 12.7059 - accuracy: 0.1113 - val_loss: 10.2349 - val_accuracy: 0.1108 - lr: 0.0010
# Epoch 34/100
# 439/439 [==============================] - 26s 60ms/step - loss: 12.6662 - accuracy: 0.1115 - val_loss: 10.3468 - val_accuracy: 0.1145 - lr: 0.0010
# Epoch 35/100
# 439/439 [==============================] - 26s 60ms/step - loss: 12.6464 - accuracy: 0.1131 - val_loss: 10.2945 - val_accuracy: 0.1204 - lr: 0.0010
# Epoch 36/100
# 439/439 [==============================] - 26s 60ms/step - loss: 12.6420 - accuracy: 0.1144 - val_loss: 10.2878 - val_accuracy: 0.1194 - lr: 0.0010
# Epoch 37/100
# 439/439 [==============================] - 26s 60ms/step - loss: 12.5765 - accuracy: 0.1166 - val_loss: 10.1976 - val_accuracy: 0.1208 - lr: 0.0010
# Epoch 38/100
# 439/439 [==============================] - 27s 61ms/step - loss: 12.5768 - accuracy: 0.1176 - val_loss: 10.1216 - val_accuracy: 0.1141 - lr: 0.0010
# Epoch 39/100
# 439/439 [==============================] - 27s 61ms/step - loss: 12.5252 - accuracy: 0.1200 - val_loss: 10.2013 - val_accuracy: 0.1057 - lr: 0.0010
# Epoch 40/100
# 439/439 [==============================] - 27s 61ms/step - loss: 12.4625 - accuracy: 0.1193 - val_loss: 10.2100 - val_accuracy: 0.1231 - lr: 0.0010
# Epoch 41/100
# 439/439 [==============================] - 27s 61ms/step - loss: 12.4334 - accuracy: 0.1244 - val_loss: 9.9818 - val_accuracy: 0.1166 - lr: 0.0010
# Epoch 42/100
# 439/439 [==============================] - 27s 60ms/step - loss: 12.4767 - accuracy: 0.1228 - val_loss: 10.3402 - val_accuracy: 0.1612 - lr: 0.0010
# Epoch 43/100
# 439/439 [==============================] - 26s 60ms/step - loss: 12.4353 - accuracy: 0.1246 - val_loss: 10.0314 - val_accuracy: 0.1180 - lr: 0.0010
# Epoch 44/100
# 439/439 [==============================] - 27s 61ms/step - loss: 12.4167 - accuracy: 0.1252 - val_loss: 10.7777 - val_accuracy: 0.1302 - lr: 0.0010
# Epoch 45/100
# 439/439 [==============================] - 28s 64ms/step - loss: 12.4019 - accuracy: 0.1269 - val_loss: 9.9221 - val_accuracy: 0.1237 - lr: 0.0010
# Epoch 46/100
# 439/439 [==============================] - 27s 61ms/step - loss: 12.3633 - accuracy: 0.1277 - val_loss: 9.8502 - val_accuracy: 0.1244 - lr: 0.0010
# Epoch 47/100
# 439/439 [==============================] - 27s 60ms/step - loss: 12.3418 - accuracy: 0.1286 - val_loss: 9.8734 - val_accuracy: 0.1237 - lr: 0.0010
# Epoch 48/100
# 439/439 [==============================] - 27s 61ms/step - loss: 12.3000 - accuracy: 0.1322 - val_loss: 9.9447 - val_accuracy: 0.1366 - lr: 0.0010
# Epoch 49/100
# 439/439 [==============================] - 27s 61ms/step - loss: 12.2875 - accuracy: 0.1319 - val_loss: 9.8079 - val_accuracy: 0.1326 - lr: 0.0010
# Epoch 50/100
# 439/439 [==============================] - 26s 59ms/step - loss: 12.2847 - accuracy: 0.1334 - val_loss: 10.1358 - val_accuracy: 0.1227 - lr: 0.0010
# Epoch 51/100
# 439/439 [==============================] - 28s 64ms/step - loss: 12.2501 - accuracy: 0.1339 - val_loss: 10.0985 - val_accuracy: 0.1562 - lr: 0.0010
# Epoch 52/100
# 439/439 [==============================] - 26s 59ms/step - loss: 12.2434 - accuracy: 0.1354 - val_loss: 9.8343 - val_accuracy: 0.1342 - lr: 0.0010
# Epoch 53/100
# 439/439 [==============================] - 26s 59ms/step - loss: 12.1977 - accuracy: 0.1367 - val_loss: 10.1608 - val_accuracy: 0.1256 - lr: 0.0010
# Epoch 54/100
# 439/439 [==============================] - 26s 59ms/step - loss: 12.2087 - accuracy: 0.1381 - val_loss: 9.8125 - val_accuracy: 0.1354 - lr: 0.0010
# Epoch 55/100
# 439/439 [==============================] - 26s 60ms/step - loss: 12.2090 - accuracy: 0.1361 - val_loss: 9.7480 - val_accuracy: 0.1258 - lr: 0.0010
# Epoch 56/100
# 439/439 [==============================] - 26s 59ms/step - loss: 12.1588 - accuracy: 0.1384 - val_loss: 9.9931 - val_accuracy: 0.1370 - lr: 0.0010
# Epoch 57/100
# 439/439 [==============================] - 28s 63ms/step - loss: 12.2023 - accuracy: 0.1397 - val_loss: 9.9179 - val_accuracy: 0.1293 - lr: 0.0010
# Epoch 58/100
# 439/439 [==============================] - 27s 61ms/step - loss: 12.0825 - accuracy: 0.1402 - val_loss: 9.8714 - val_accuracy: 0.1333 - lr: 0.0010
# Epoch 59/100
# 439/439 [==============================] - 26s 60ms/step - loss: 12.1268 - accuracy: 0.1394 - val_loss: 10.0692 - val_accuracy: 0.1261 - lr: 0.0010
# Epoch 60/100
# 439/439 [==============================] - 26s 60ms/step - loss: 12.0937 - accuracy: 0.1421 - val_loss: 9.7093 - val_accuracy: 0.1380 - lr: 0.0010
# Epoch 61/100
# 439/439 [==============================] - 26s 59ms/step - loss: 12.0955 - accuracy: 0.1420 - val_loss: 11.0382 - val_accuracy: 0.1384 - lr: 0.0010
# Epoch 62/100
# 439/439 [==============================] - 26s 59ms/step - loss: 12.1034 - accuracy: 0.1425 - val_loss: 9.7899 - val_accuracy: 0.1368 - lr: 0.0010
# Epoch 63/100
# 439/439 [==============================] - 28s 64ms/step - loss: 12.0601 - accuracy: 0.1434 - val_loss: 10.3738 - val_accuracy: 0.1497 - lr: 0.0010
# Epoch 64/100
# 439/439 [==============================] - 27s 61ms/step - loss: 12.0598 - accuracy: 0.1446 - val_loss: 9.7476 - val_accuracy: 0.1261 - lr: 0.0010
# Epoch 65/100
# 439/439 [==============================] - 27s 60ms/step - loss: 12.0185 - accuracy: 0.1445 - val_loss: 9.7775 - val_accuracy: 0.1320 - lr: 0.0010
# Epoch 66/100
# 439/439 [==============================] - 26s 60ms/step - loss: 11.9966 - accuracy: 0.1460 - val_loss: 9.8649 - val_accuracy: 0.1286 - lr: 0.0010
# Epoch 67/100
# 439/439 [==============================] - 26s 60ms/step - loss: 11.9732 - accuracy: 0.1452 - val_loss: 9.6951 - val_accuracy: 0.1432 - lr: 0.0010
# Epoch 68/100
# 439/439 [==============================] - 26s 60ms/step - loss: 11.9735 - accuracy: 0.1460 - val_loss: 9.6682 - val_accuracy: 0.1392 - lr: 0.0010
# Epoch 69/100
# 439/439 [==============================] - 26s 60ms/step - loss: 11.9641 - accuracy: 0.1468 - val_loss: 9.9030 - val_accuracy: 0.1499 - lr: 0.0010
# Epoch 70/100
# 439/439 [==============================] - 28s 64ms/step - loss: 11.9477 - accuracy: 0.1478 - val_loss: 9.7668 - val_accuracy: 0.1347 - lr: 0.0010
# Epoch 71/100
# 439/439 [==============================] - 26s 60ms/step - loss: 11.9625 - accuracy: 0.1467 - val_loss: 9.7389 - val_accuracy: 0.1351 - lr: 0.0010
# Epoch 72/100
# 439/439 [==============================] - 26s 60ms/step - loss: 11.9481 - accuracy: 0.1475 - val_loss: 9.8381 - val_accuracy: 0.1319 - lr: 0.0010
# Epoch 73/100
# 439/439 [==============================] - 26s 60ms/step - loss: 11.9122 - accuracy: 0.1490 - val_loss: 9.6241 - val_accuracy: 0.1341 - lr: 0.0010
# Epoch 74/100
# 439/439 [==============================] - 26s 60ms/step - loss: 11.9549 - accuracy: 0.1491 - val_loss: 9.7724 - val_accuracy: 0.1473 - lr: 0.0010
# Epoch 75/100
# 439/439 [==============================] - 26s 60ms/step - loss: 11.9116 - accuracy: 0.1495 - val_loss: 9.5625 - val_accuracy: 0.1284 - lr: 0.0010
# Epoch 76/100
# 439/439 [==============================] - 28s 64ms/step - loss: 11.8949 - accuracy: 0.1508 - val_loss: 9.5724 - val_accuracy: 0.1387 - lr: 0.0010
# Epoch 77/100
# 439/439 [==============================] - 26s 59ms/step - loss: 11.8818 - accuracy: 0.1507 - val_loss: 9.7702 - val_accuracy: 0.1340 - lr: 0.0010
# Epoch 78/100
# 439/439 [==============================] - 26s 60ms/step - loss: 11.8545 - accuracy: 0.1533 - val_loss: 9.8237 - val_accuracy: 0.1465 - lr: 0.0010
# Epoch 79/100
# 439/439 [==============================] - 26s 60ms/step - loss: 11.8635 - accuracy: 0.1528 - val_loss: 9.7552 - val_accuracy: 0.1451 - lr: 0.0010
# Epoch 80/100
# 439/439 [==============================] - 26s 60ms/step - loss: 11.8916 - accuracy: 0.1540 - val_loss: 9.6484 - val_accuracy: 0.1462 - lr: 0.0010
# Epoch 81/100
# 439/439 [==============================] - 29s 67ms/step - loss: 11.8258 - accuracy: 0.1527 - val_loss: 9.6044 - val_accuracy: 0.1429 - lr: 0.0010
# Epoch 82/100
# 439/439 [==============================] - 28s 64ms/step - loss: 11.8366 - accuracy: 0.1533 - val_loss: 9.6497 - val_accuracy: 0.1512 - lr: 0.0010
# Epoch 83/100
# 439/439 [==============================] - 27s 61ms/step - loss: 11.8888 - accuracy: 0.1526 - val_loss: 9.6037 - val_accuracy: 0.1411 - lr: 0.0010
# Epoch 84/100
# 439/439 [==============================] - 28s 63ms/step - loss: 11.8246 - accuracy: 0.1546 - val_loss: 9.5791 - val_accuracy: 0.1368 - lr: 0.0010
# Epoch 85/100
# 439/439 [==============================] - 27s 61ms/step - loss: 11.8567 - accuracy: 0.1531 - val_loss: 9.5127 - val_accuracy: 0.1311 - lr: 0.0010
# Epoch 86/100
# 439/439 [==============================] - 27s 61ms/step - loss: 11.8371 - accuracy: 0.1541 - val_loss: 9.6072 - val_accuracy: 0.1415 - lr: 0.0010
# Epoch 87/100
# 439/439 [==============================] - 27s 61ms/step - loss: 11.7943 - accuracy: 0.1559 - val_loss: 9.4506 - val_accuracy: 0.1403 - lr: 0.0010
# Epoch 88/100
# 439/439 [==============================] - 28s 64ms/step - loss: 11.7925 - accuracy: 0.1564 - val_loss: 9.8069 - val_accuracy: 0.1323 - lr: 0.0010
# Epoch 89/100
# 439/439 [==============================] - 27s 60ms/step - loss: 11.8484 - accuracy: 0.1565 - val_loss: 9.5654 - val_accuracy: 0.1400 - lr: 0.0010
# Epoch 90/100
# 439/439 [==============================] - 26s 60ms/step - loss: 11.7390 - accuracy: 0.1579 - val_loss: 9.5191 - val_accuracy: 0.1504 - lr: 0.0010
# Epoch 91/100
# 439/439 [==============================] - 26s 60ms/step - loss: 11.7780 - accuracy: 0.1561 - val_loss: 9.4451 - val_accuracy: 0.1354 - lr: 0.0010
# Epoch 92/100
# 439/439 [==============================] - 27s 60ms/step - loss: 11.8408 - accuracy: 0.1558 - val_loss: 9.5612 - val_accuracy: 0.1401 - lr: 0.0010
# Epoch 93/100
# 439/439 [==============================] - 26s 60ms/step - loss: 11.7744 - accuracy: 0.1587 - val_loss: 9.4651 - val_accuracy: 0.1603 - lr: 0.0010
# Epoch 94/100
# 439/439 [==============================] - 28s 64ms/step - loss: 11.7473 - accuracy: 0.1583 - val_loss: 9.8526 - val_accuracy: 0.1485 - lr: 0.0010
# Epoch 95/100
# 439/439 [==============================] - 27s 60ms/step - loss: 11.8327 - accuracy: 0.1568 - val_loss: 9.7862 - val_accuracy: 0.1394 - lr: 0.0010
# Epoch 96/100
# 439/439 [==============================] - 26s 59ms/step - loss: 11.7552 - accuracy: 0.1589 - val_loss: 9.6371 - val_accuracy: 0.1366 - lr: 0.0010
# Epoch 97/100
# 439/439 [==============================] - 26s 59ms/step - loss: 11.7383 - accuracy: 0.1591 - val_loss: 9.4606 - val_accuracy: 0.1372 - lr: 0.0010
# Epoch 98/100
# 439/439 [==============================] - 26s 60ms/step - loss: 11.7893 - accuracy: 0.1585 - val_loss: 9.7045 - val_accuracy: 0.1426 - lr: 0.0010
# Epoch 99/100
# 439/439 [==============================] - 27s 61ms/step - loss: 11.7322 - accuracy: 0.1580 - val_loss: 9.4086 - val_accuracy: 0.1504 - lr: 0.0010
# Epoch 100/100
# 439/439 [==============================] - 28s 64ms/step - loss: 11.7253 - accuracy: 0.1585 - val_loss: 9.6344 - val_accuracy: 0.1402 - lr: 0.0010

# %%
xtest = x[-200:]
xtest = np.array(xtest).reshape(1, 200, 1)

# %%
keras_model_best = keras.models.load_model('best_model.h5', custom_objects={'root_mean_squared_error': root_mean_squared_error})

y_predict = keras_model_best.predict(xtest, verbose=1)

y_predict = y_predict[0]
# Out:
# 1/1 [==============================] - 0s 370ms/step

# %%
raw_data.iloc[consecutive] = y_predict

# %%
# unconsecutive 부분 보간

unconsecutive2 = [unconsecutive-1, unconsecutive, unconsecutive+1]
raw_data.iloc[unconsecutive2] = raw_data.iloc[unconsecutive2].interpolate()

# %%
raw_data.isnull().sum()
# Out:
# 0

# %%
raw_data.to_csv('/content/drive/MyDrive/신입기수 프로젝트/Dataset/CNN_전처리/행주대교_수위_6th.csv', index = False, encoding = 'cp949')

# %%
start  = consecutive[0] -200
end = consecutive[-1] + 200

x1 = range(len(raw_data[start : end]))
y1 = raw_data[start:end]
plt.plot(x1, y1)
