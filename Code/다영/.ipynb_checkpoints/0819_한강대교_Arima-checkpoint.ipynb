# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/신입기수 프로젝트/Dataset/rawdata.csv')

# %%
x1 = df['강화대교_조위'][500:3000]
plt.plot(x1)
plt.show()
plt.figure(figsize=(30, 15))
