# %% [markdown]
# ### 한강대교 유량 결측치 처리
# 1. 사용할 컬럼: 자기 자신 -> 청담대교 수위 -> 행주대교 유량 -> 잠수교 수위 -> 청담대교 유량 -> 광진교 유량 -> 한강대교 수위 -> 강화대교 조위 -> 방류량 -> 강수량... -> 행주대교 수위
# 2. 그런데 이 순서는 모델의 행동을 설명하는 것이지 인과관계를 반드시 보장한다고 할 수는 없음...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings(action='ignore')

import time
from glob import glob
from tqdm import tqdm

import tensorflow as tf
import tensorflow.keras as keras
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras import backend as K
# from keras.utils import plot_model

from keras.layers import Activation, Dense, LSTM, GRU, Bidirectional, AveragePooling1D, GlobalAveragePooling1D, Dropout, Flatten, BatchNormalization, TimeDistributed, Input, Reshape, RepeatVector, Concatenate, GlobalMaxPooling1D 
from keras.layers.convolutional import Conv1D, MaxPooling1D, AveragePooling1D


#GPU 자원이 부족
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
import os
os.chdir('/content/drive/MyDrive/신입기수 프로젝트/Dataset/')

# %%
# 결측치 처리한 수위4개+유량1개 데이터셋 가져오기
raw_data = pd.read_csv('Copy of 0827 광진행주유량수위x4.csv', encoding = 'cp949')

# 6912개 수위데이터 + 한강대교_수위 데이터셋 가져오기
newdata5 = pd.read_csv('newdata5.csv', encoding = 'cp949')

# 한강대교 수위 컬럼 추가
raw_data = pd.concat([raw_data, newdata5['청담대교_유량']], axis = 1)

# 6912개 수위 데이터 replace
raw_data.iloc[-6912:, [2, 3, 4, 5]] = newdata5.iloc[-6912:, [-4, -3, -2, -1]]

# %%
raw_data
# Out:
#         광진교_수위  행주대교_유량  청담대교_수위  잠수교_수위  한강대교_수위  행주대교_수위  청담대교_유량
# 0         1.20   540.18    310.7   300.2    290.0    275.3   469.05
# 1         1.20   540.18    314.7   300.2    290.0    275.3   498.00
# 2         1.20   540.18    313.7   301.2    290.0    275.3   490.68
# 3         1.20   552.17    311.7   301.2    290.0    276.3   476.21
# 4         1.20   564.29    311.7   301.2    291.0    277.3   476.21
# ...        ...      ...      ...     ...      ...      ...      ...
# 276331    1.12   974.40    288.0   295.0    299.0    306.0   319.84
# 276332    1.12  1006.88    287.0   303.0    304.0    308.0   314.01
# 276333    1.12  1039.90    299.0   307.0    309.0    310.0   387.55
# 276334    1.12  1073.46    309.0   311.0    314.0    312.0   454.91
# 276335    1.12  1090.45    326.0   314.0    317.0    313.0   582.21
#
# [276336 rows x 7 columns]

# %%
x = raw_data[['청담대교_수위', '잠수교_수위',	'한강대교_수위', '광진교_수위',	'행주대교_유량', '청담대교_유량']]

# %%
x
# Out:
#         청담대교_수위  잠수교_수위  한강대교_수위  광진교_수위  행주대교_유량  청담대교_유량
# 0         310.7   300.2    290.0    1.20   540.18   469.05
# 1         314.7   300.2    290.0    1.20   540.18   498.00
# 2         313.7   301.2    290.0    1.20   540.18   490.68
# 3         311.7   301.2    290.0    1.20   552.17   476.21
# 4         311.7   301.2    291.0    1.20   564.29   476.21
# ...         ...     ...      ...     ...      ...      ...
# 276331    288.0   295.0    299.0    1.12   974.40   319.84
# 276332    287.0   303.0    304.0    1.12  1006.88   314.01
# 276333    299.0   307.0    309.0    1.12  1039.90   387.55
# 276334    309.0   311.0    314.0    1.12  1073.46   454.91
# 276335    326.0   314.0    317.0    1.12  1090.45   582.21
#
# [276336 rows x 6 columns]

# %%
# 정규화
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

input_x_regular = x.copy()

for i in range(len(x.columns)):
    scaler = MinMaxScaler()                       #StandardScaler() , MinMaxScaler() , RobustScaler()
    a=np.array(input_x_regular.iloc[:,i])
    tmp_x = scaler.fit_transform(a.reshape(-1,1))
    input_x_regular.iloc[:,i] = tmp_x

# %% [markdown]
# # 원하는 칼럼명 입력하기

# %%
#ydata = raw_data[['현재수위','유입량','저수량','공용량','방류량','강화대교_조위','청담대교_유량','잠수교_유량','한강대교_유량']]
y = raw_data['청담대교_유량']

# %% [markdown]
# # 원하는 칼럼명 입력하기

# %%
input_regular = pd.concat([input_x_regular, y], axis = 1)
input_regular
# Out:
#          청담대교_수위    잠수교_수위   한강대교_수위    광진교_수위   행주대교_유량   청담대교_유량  청담대교_유량
# 0       0.049611  0.060000  0.051621  0.056452  0.011070  0.024640   469.05
# 1       0.053502  0.060000  0.051621  0.056452  0.011070  0.027800   498.00
# 2       0.052529  0.061111  0.051621  0.056452  0.011070  0.027001   490.68
# 3       0.050584  0.061111  0.051621  0.056452  0.011475  0.025421   476.21
# 4       0.050584  0.061111  0.052821  0.056452  0.011883  0.025421   476.21
# ...          ...       ...       ...       ...       ...       ...      ...
# 276331  0.027529  0.054222  0.062425  0.045699  0.025719  0.008355   319.84
# 276332  0.026556  0.063111  0.068427  0.045699  0.026815  0.007719   314.01
# 276333  0.038230  0.067556  0.074430  0.045699  0.027929  0.015745   387.55
# 276334  0.047957  0.072000  0.080432  0.045699  0.029061  0.023097   454.91
# 276335  0.064494  0.075333  0.084034  0.045699  0.029634  0.036991   582.21
#
# [276336 rows x 7 columns]

# %% [markdown]
# # 원하는 칼럼명 입력하기

# %%
df_nanindex = pd.read_csv('/content/drive/MyDrive/신입기수 프로젝트/Dataset/rawdata.csv')

nanIndex = df_nanindex[df_nanindex['청담대교_유량'].isnull() == True].index

# %%
nanIndex
# Out:
# Int64Index([ 80994,  80995,  80996,  80997,  80998,  80999,  81000,  81001,
#              81002,  81003,
#             ...
#             273770, 273771, 273772, 273773, 273774, 273775, 273776, 273777,
#             273778, 273779],
#            dtype='int64', length=16380)

# %%
from tqdm import tqdm

xdata = []
ydata = []
xdata_idx = []
ydata_idx = [-1]
for i in range(len(input_regular.columns)-1):
    xdata_idx.append(i)

w =  6 #window size

idx = []
for i in range(12):
  idx.append(i*26496)

for i in tqdm(range(11)):
    if i != 10:
        tmp = input_regular[idx[i]:idx[i+1]]
    else:
        tmp = input_regular[idx[i]:]

    for j in range(len(tmp)-w):
        xdata.append(np.array(tmp.iloc[j:j + w, xdata_idx]).astype(float))

    for j in range(w,len(tmp)):
        ydata.append(np.array(tmp.iloc[j, ydata_idx]).astype(float))
# Out:
# 100%|██████████| 11/11 [02:12<00:00, 12.06s/it]

# %%
print(np.array(xdata).shape)
print(np.array(ydata).shape)
# Out:
# (276270, 6, 6)
# (276270, 1)

# %%
# 나중에 학습된 모델에 이거 넣어서 predict해서 결측치 채우기
x_real_predict = []
y_real_predict = []

for i in range(len(nanIndex)):
    k = nanIndex[-(i+1)]
    
    x_real_predict.insert(0,(xdata[k - w * (k // 26496 + 1)]))
    y_real_predict.insert(0,(ydata[k - w * (k // 26496 + 1)]))
    
    xdata.pop(k - w * (k // 26496 + 1))
    ydata.pop(k - w * (k // 26496 + 1))

# %%
print(np.array(x_real_predict).shape)
print(np.array(y_real_predict).shape)
# Out:
# (16380, 6, 6)
# (16380, 1)

# %%
print(np.array(xdata).shape)
print(np.array(ydata).shape)
# Out:
# (259890, 6, 6)
# (259890, 1)

# %%
pd.DataFrame(ydata).isnull().sum()
# Out:
# 0    0
# dtype: int64

# %%
xtrain = np.array(xdata[:-50000])
ytrain = np.array(ydata[:-50000])

xtest = np.array(xdata[-50000:])
ytest = np.array(ydata[-50000:])

# %%
print(xtrain.shape)
print(ytrain.shape)
print(xtest.shape)
print(ytest.shape)
# Out:
# (209890, 6, 6)
# (209890, 1)
# (50000, 6, 6)
# (50000, 1)

# %% [markdown]
# ## 모델 생성

# %%
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true))) 

if 'model_enc_dec_cnn' in locals(): 
    del model_enc_dec_cnn 
if 'history' in locals():
    del history

optimizer = tf.keras.optimizers.Adam(lr=0.01) #기본값 0.001

model_enc_dec_cnn = Sequential()
model_enc_dec_cnn.add(Conv1D(filters=64, kernel_size=2, padding = 'causal', activation='relu', input_shape=(w, xtrain.shape[2])))
#model_enc_dec_cnn.add(Conv1D(filters=64, kernel_size=2, padding = 'causal', activation='relu'))
#model_enc_dec_cnn.add(MaxPooling1D(pool_size=2))
model_enc_dec_cnn.add(Flatten())

model_enc_dec_cnn.add(RepeatVector(1))
model_enc_dec_cnn.add(GRU(200, activation='relu', return_sequences=True))
model_enc_dec_cnn.add(GRU(200, activation='relu', return_sequences=True))
# model_enc_dec_cnn.add(LSTM(200, activation='relu', return_sequences=True))
# model_enc_dec_cnn.add(LSTM(200, activation='relu', return_sequences=True))
# model_enc_dec_cnn.add(LSTM(200, activation='relu', return_sequences=True))
model_enc_dec_cnn.add(GRU(200, activation='relu'))

model_enc_dec_cnn.add(Dense(100, activation='relu'))
model_enc_dec_cnn.add(Dense(1))

model_enc_dec_cnn.compile(loss=root_mean_squared_error, optimizer=optimizer, metrics =["accuracy"])

model_enc_dec_cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 6, 64)             832
#
#  flatten (Flatten)           (None, 384)               0
#
#  repeat_vector (RepeatVector  (None, 1, 384)           0
#  )
#
#  gru (GRU)                   (None, 1, 200)            351600
#
#  gru_1 (GRU)                 (None, 1, 200)            241200
#
#  gru_2 (GRU)                 (None, 200)               241200
#
#  dense (Dense)               (None, 100)               20100
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 855,033
# Trainable params: 855,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
# plot_model(model=model_enc_dec_cnn, show_shapes=True)

# %%
epochs = 100
batch_size = xtrain.shape[0] // 1000
validation = 0.2

checkpoint_callback = ModelCheckpoint(filepath='best_model.h5', save_weights_only=False, monitor='val_loss',
                                         mode='min', save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', min_delta=0.005, patience=10, mode='min')
rlrop_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, mode='min', patience=3, min_lr=0.001)

# %%
## 학습

history = model_enc_dec_cnn.fit(xtrain, ytrain, verbose=1, epochs=epochs, batch_size=batch_size, validation_split=validation,callbacks=[early_stopping_callback, checkpoint_callback, rlrop_callback])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 24s 26ms/step - loss: 119.1742 - accuracy: 0.0000e+00 - val_loss: 27.1654 - val_accuracy: 0.0000e+00 - lr: 0.0100
# Epoch 2/100
# 804/804 [==============================] - 20s 25ms/step - loss: 68.4150 - accuracy: 0.0000e+00 - val_loss: 50.6957 - val_accuracy: 0.0000e+00 - lr: 0.0100
# Epoch 3/100
# 804/804 [==============================] - 20s 25ms/step - loss: 57.9489 - accuracy: 0.0000e+00 - val_loss: 27.6999 - val_accuracy: 0.0000e+00 - lr: 0.0100
# Epoch 4/100
# 804/804 [==============================] - 20s 25ms/step - loss: 48.3252 - accuracy: 0.0000e+00 - val_loss: 30.9470 - val_accuracy: 0.0000e+00 - lr: 0.0100
# Epoch 5/100
# 804/804 [==============================] - 20s 25ms/step - loss: 28.4802 - accuracy: 0.0000e+00 - val_loss: 19.6105 - val_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 6/100
# 804/804 [==============================] - 20s 25ms/step - loss: 27.3827 - accuracy: 0.0000e+00 - val_loss: 23.0414 - val_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 7/100
# 804/804 [==============================] - 20s 25ms/step - loss: 27.3702 - accuracy: 0.0000e+00 - val_loss: 14.6196 - val_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 8/100
# 804/804 [==============================] - 20s 25ms/step - loss: 27.3054 - accuracy: 0.0000e+00 - val_loss: 21.6309 - val_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 9/100
# 804/804 [==============================] - 20s 25ms/step - loss: 23.6555 - accuracy: 0.0000e+00 - val_loss: 15.0079 - val_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 10/100
# 804/804 [==============================] - 20s 25ms/step - loss: 24.1752 - accuracy: 0.0000e+00 - val_loss: 23.8552 - val_accuracy: 0.0000e+00 - lr: 0.0050
# Epoch 11/100
# 804/804 [==============================] - 20s 25ms/step - loss: 18.9312 - accuracy: 0.0000e+00 - val_loss: 15.3298 - val_accuracy: 0.0000e+00 - lr: 0.0025
# Epoch 12/100
# 804/804 [==============================] - 20s 25ms/step - loss: 18.9377 - accuracy: 0.0000e+00 - val_loss: 12.8993 - val_accuracy: 0.0000e+00 - lr: 0.0025
# Epoch 13/100
# 804/804 [==============================] - 20s 25ms/step - loss: 18.9341 - accuracy: 0.0000e+00 - val_loss: 13.0982 - val_accuracy: 0.0000e+00 - lr: 0.0025
# Epoch 14/100
# 804/804 [==============================] - 20s 25ms/step - loss: 20.2220 - accuracy: 0.0000e+00 - val_loss: 13.0294 - val_accuracy: 0.0000e+00 - lr: 0.0025
# Epoch 15/100
# 804/804 [==============================] - 20s 25ms/step - loss: 18.8377 - accuracy: 0.0000e+00 - val_loss: 12.2677 - val_accuracy: 0.0000e+00 - lr: 0.0025
# Epoch 16/100
# 804/804 [==============================] - 20s 25ms/step - loss: 18.6638 - accuracy: 0.0000e+00 - val_loss: 14.4765 - val_accuracy: 0.0000e+00 - lr: 0.0025
# Epoch 17/100
# 804/804 [==============================] - 20s 25ms/step - loss: 19.1104 - accuracy: 0.0000e+00 - val_loss: 12.3449 - val_accuracy: 0.0000e+00 - lr: 0.0025
# Epoch 18/100
# 804/804 [==============================] - 21s 26ms/step - loss: 18.5354 - accuracy: 0.0000e+00 - val_loss: 13.7984 - val_accuracy: 0.0000e+00 - lr: 0.0025
# Epoch 19/100
# 804/804 [==============================] - 21s 26ms/step - loss: 16.0652 - accuracy: 0.0000e+00 - val_loss: 11.5030 - val_accuracy: 0.0000e+00 - lr: 0.0012
# Epoch 20/100
# 804/804 [==============================] - 21s 26ms/step - loss: 15.6981 - accuracy: 0.0000e+00 - val_loss: 10.8550 - val_accuracy: 0.0000e+00 - lr: 0.0012
# Epoch 21/100
# 804/804 [==============================] - 20s 25ms/step - loss: 15.9995 - accuracy: 0.0000e+00 - val_loss: 11.2660 - val_accuracy: 0.0000e+00 - lr: 0.0012
# Epoch 22/100
# 804/804 [==============================] - 20s 25ms/step - loss: 16.0576 - accuracy: 0.0000e+00 - val_loss: 11.3351 - val_accuracy: 0.0000e+00 - lr: 0.0012
# Epoch 23/100
# 804/804 [==============================] - 20s 25ms/step - loss: 15.8749 - accuracy: 0.0000e+00 - val_loss: 12.1073 - val_accuracy: 0.0000e+00 - lr: 0.0012
# Epoch 24/100
# 804/804 [==============================] - 21s 27ms/step - loss: 15.3274 - accuracy: 0.0000e+00 - val_loss: 10.6098 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 25/100
# 804/804 [==============================] - 20s 25ms/step - loss: 15.1858 - accuracy: 0.0000e+00 - val_loss: 10.6285 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 26/100
# 804/804 [==============================] - 20s 25ms/step - loss: 15.2889 - accuracy: 0.0000e+00 - val_loss: 11.0816 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 27/100
# 804/804 [==============================] - 20s 25ms/step - loss: 15.4975 - accuracy: 0.0000e+00 - val_loss: 12.2887 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 28/100
# 804/804 [==============================] - 20s 25ms/step - loss: 15.5025 - accuracy: 0.0000e+00 - val_loss: 12.3352 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 29/100
# 804/804 [==============================] - 21s 26ms/step - loss: 15.0704 - accuracy: 0.0000e+00 - val_loss: 12.7334 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 30/100
# 804/804 [==============================] - 21s 26ms/step - loss: 15.3016 - accuracy: 0.0000e+00 - val_loss: 10.3823 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 31/100
# 804/804 [==============================] - 21s 26ms/step - loss: 15.3386 - accuracy: 0.0000e+00 - val_loss: 10.3750 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 32/100
# 804/804 [==============================] - 20s 25ms/step - loss: 15.3861 - accuracy: 0.0000e+00 - val_loss: 10.3900 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 33/100
# 804/804 [==============================] - 20s 25ms/step - loss: 15.4326 - accuracy: 0.0000e+00 - val_loss: 10.8874 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 34/100
# 804/804 [==============================] - 21s 26ms/step - loss: 15.1731 - accuracy: 0.0000e+00 - val_loss: 11.1127 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 35/100
# 804/804 [==============================] - 20s 25ms/step - loss: 15.1578 - accuracy: 0.0000e+00 - val_loss: 10.3891 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 36/100
# 804/804 [==============================] - 20s 25ms/step - loss: 15.0809 - accuracy: 0.0000e+00 - val_loss: 10.4808 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 37/100
# 804/804 [==============================] - 20s 25ms/step - loss: 15.2681 - accuracy: 0.0000e+00 - val_loss: 10.8671 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 38/100
# 804/804 [==============================] - 21s 26ms/step - loss: 15.2529 - accuracy: 0.0000e+00 - val_loss: 10.0661 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 39/100
# 804/804 [==============================] - 21s 26ms/step - loss: 15.0097 - accuracy: 0.0000e+00 - val_loss: 11.5666 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 40/100
# 804/804 [==============================] - 20s 25ms/step - loss: 15.0783 - accuracy: 0.0000e+00 - val_loss: 12.8577 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 41/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.6838 - accuracy: 0.0000e+00 - val_loss: 10.2677 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 42/100
# 804/804 [==============================] - 20s 25ms/step - loss: 15.2229 - accuracy: 0.0000e+00 - val_loss: 11.9723 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 43/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.9763 - accuracy: 0.0000e+00 - val_loss: 10.4680 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 44/100
# 804/804 [==============================] - 21s 27ms/step - loss: 14.8848 - accuracy: 0.0000e+00 - val_loss: 9.9961 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 45/100
# 804/804 [==============================] - 21s 26ms/step - loss: 14.8561 - accuracy: 0.0000e+00 - val_loss: 10.0686 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 46/100
# 804/804 [==============================] - 20s 25ms/step - loss: 15.2036 - accuracy: 0.0000e+00 - val_loss: 10.5524 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 47/100
# 804/804 [==============================] - 21s 26ms/step - loss: 14.8902 - accuracy: 0.0000e+00 - val_loss: 9.9511 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 48/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.7857 - accuracy: 0.0000e+00 - val_loss: 11.0870 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 49/100
# 804/804 [==============================] - 21s 26ms/step - loss: 15.0917 - accuracy: 0.0000e+00 - val_loss: 10.5751 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 50/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.8524 - accuracy: 0.0000e+00 - val_loss: 10.0047 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 51/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.9922 - accuracy: 0.0000e+00 - val_loss: 10.9433 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 52/100
# 804/804 [==============================] - 21s 26ms/step - loss: 14.8837 - accuracy: 0.0000e+00 - val_loss: 9.9018 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 53/100
# 804/804 [==============================] - 20s 25ms/step - loss: 15.0335 - accuracy: 0.0000e+00 - val_loss: 11.1836 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 54/100
# 804/804 [==============================] - 22s 27ms/step - loss: 14.7887 - accuracy: 0.0000e+00 - val_loss: 9.8317 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 55/100
# 804/804 [==============================] - 21s 26ms/step - loss: 14.5982 - accuracy: 0.0000e+00 - val_loss: 10.7978 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 56/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.7379 - accuracy: 0.0000e+00 - val_loss: 10.8434 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 57/100
# 804/804 [==============================] - 21s 26ms/step - loss: 15.0202 - accuracy: 0.0000e+00 - val_loss: 9.6703 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 58/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.7416 - accuracy: 0.0000e+00 - val_loss: 10.4491 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 59/100
# 804/804 [==============================] - 21s 26ms/step - loss: 14.7509 - accuracy: 0.0000e+00 - val_loss: 10.3439 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 60/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.8534 - accuracy: 0.0000e+00 - val_loss: 10.0356 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 61/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.5549 - accuracy: 0.0000e+00 - val_loss: 11.3360 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 62/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.9247 - accuracy: 0.0000e+00 - val_loss: 9.9751 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 63/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.7699 - accuracy: 0.0000e+00 - val_loss: 11.1330 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 64/100
# 804/804 [==============================] - 21s 27ms/step - loss: 14.8961 - accuracy: 0.0000e+00 - val_loss: 9.5856 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 65/100
# 804/804 [==============================] - 21s 26ms/step - loss: 14.6756 - accuracy: 0.0000e+00 - val_loss: 10.0630 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 66/100
# 804/804 [==============================] - 23s 29ms/step - loss: 14.7790 - accuracy: 0.0000e+00 - val_loss: 9.6282 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 67/100
# 804/804 [==============================] - 24s 30ms/step - loss: 14.7302 - accuracy: 0.0000e+00 - val_loss: 10.3018 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 68/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.7091 - accuracy: 0.0000e+00 - val_loss: 9.7693 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 69/100
# 804/804 [==============================] - 22s 27ms/step - loss: 14.6494 - accuracy: 0.0000e+00 - val_loss: 9.7268 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 70/100
# 804/804 [==============================] - 21s 26ms/step - loss: 14.4742 - accuracy: 0.0000e+00 - val_loss: 10.2527 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 71/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.4490 - accuracy: 0.0000e+00 - val_loss: 9.7984 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 72/100
# 804/804 [==============================] - 21s 26ms/step - loss: 14.8835 - accuracy: 0.0000e+00 - val_loss: 9.5162 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 73/100
# 804/804 [==============================] - 21s 26ms/step - loss: 14.5387 - accuracy: 0.0000e+00 - val_loss: 10.1402 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 74/100
# 804/804 [==============================] - 21s 26ms/step - loss: 14.4250 - accuracy: 0.0000e+00 - val_loss: 9.6941 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 75/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.7025 - accuracy: 0.0000e+00 - val_loss: 10.1922 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 76/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.2995 - accuracy: 0.0000e+00 - val_loss: 9.9131 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 77/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.4784 - accuracy: 0.0000e+00 - val_loss: 9.9045 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 78/100
# 804/804 [==============================] - 21s 26ms/step - loss: 14.8814 - accuracy: 0.0000e+00 - val_loss: 9.3164 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 79/100
# 804/804 [==============================] - 21s 26ms/step - loss: 14.7372 - accuracy: 0.0000e+00 - val_loss: 9.6619 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 80/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.4353 - accuracy: 0.0000e+00 - val_loss: 11.2330 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 81/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.5819 - accuracy: 0.0000e+00 - val_loss: 10.6757 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 82/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.6616 - accuracy: 0.0000e+00 - val_loss: 9.7278 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 83/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.3238 - accuracy: 0.0000e+00 - val_loss: 9.3775 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 84/100
# 804/804 [==============================] - 21s 26ms/step - loss: 14.4396 - accuracy: 0.0000e+00 - val_loss: 13.1749 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 85/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.4886 - accuracy: 0.0000e+00 - val_loss: 9.5458 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 86/100
# 804/804 [==============================] - 20s 25ms/step - loss: 14.3941 - accuracy: 0.0000e+00 - val_loss: 9.7877 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 87/100
# 804/804 [==============================] - 21s 26ms/step - loss: 14.4370 - accuracy: 0.0000e+00 - val_loss: 9.4719 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 88/100
# 804/804 [==============================] - 21s 26ms/step - loss: 14.4135 - accuracy: 0.0000e+00 - val_loss: 9.4068 - val_accuracy: 0.0000e+00 - lr: 0.0010

# %%
## 평가

keras_model_best = keras.models.load_model('best_model.h5', custom_objects={'root_mean_squared_error': root_mean_squared_error})

yhat = keras_model_best.predict(xtest, verbose=1)

yhat

keras_model_best.evaluate(xtest,ytest)
# Out:
# 1563/1563 [==============================] - 6s 3ms/step
# 1563/1563 [==============================] - 6s 3ms/step - loss: 15.6975 - accuracy: 0.0000e+00
# [15.697497367858887, 0.0]

# %%
## 학습 과정 시각화

fig, loss_ax = plt.subplots(1, 2)
fig.set_size_inches((15,5))

loss_ax[0].plot(history.history['loss'], 'b', label='train loss')
loss_ax[0].plot(history.history['val_loss'], 'r', label='val loss')

loss_ax[1].plot(history.history['accuracy'], 'y', label='train acc')
loss_ax[1].plot(history.history['val_accuracy'], 'g', label='val acc')

loss_ax[0].set_xlabel('epoch')
loss_ax[0].set_ylabel('loss')
loss_ax[1].set_xlabel('epoch')
loss_ax[1].set_ylabel('accuray')

loss_ax[0].legend(loc='upper right')
loss_ax[1].legend(loc='lower right')

plt.show()

# %%
## 결과 시각화

tl_predict = np.array(yhat)

#결과 시각화
plt.figure(figsize=(15,10))
plt.plot(ytest, marker = ",", label = "actual")
plt.plot(tl_predict, marker = ",", label="predict", alpha = 0.5)
plt.legend(prop={'size':10})  

plt.show()

# %%
## 점수 확인
print("RMSE : ",float(root_mean_squared_error(ytest, tl_predict)))
# Out:
# RMSE :  18.560458403939922

# %% [markdown]
# ## 파일 저장

# %%
print(len(yhat))
print(len(nanIndex))
# Out:
# 50000
# 16380

# %%
x_real_predict = np.array(x_real_predict)
y_real_hat = keras_model_best.predict(x_real_predict, verbose = 1)
# Out:
# 512/512 [==============================] - 2s 4ms/step

# %%
root_mean_squared_error(y_real_predict, y_real_hat) #y_real_predict도 예측값밖에 없어서 의미없긴 하지만 얼마나 달라졌는지 보고 싶어서
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=3736.5251240024704>

# %%
print(len(y_real_hat))
print(len(nanIndex))
# Out:
# 16380
# 16380

# %%
for i in range(len(nanIndex)):
    raw_data['청담대교_유량'].iloc[nanIndex[i]] = np.float64(y_real_hat[i])

# %%
raw_data['청담대교_유량'].to_csv('/content/drive/MyDrive/신입기수 프로젝트/Dataset/newdata7_청담대교_유량_GRU.csv', index = False, encoding = 'cp949')
