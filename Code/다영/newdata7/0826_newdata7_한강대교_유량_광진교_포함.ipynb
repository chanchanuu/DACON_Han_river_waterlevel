# %% [markdown]
# ### 한강대교 유량 결측치 처리
# 1. 사용할 컬럼: 자기 자신 -> 청담대교 수위 -> 행주대교 유량 -> 잠수교 수위 -> 청담대교 유량 -> 광진교 유량 -> 한강대교 수위 -> 강화대교 조위 -> 방류량 -> 강수량... -> 행주대교 수위
# 2. 그런데 이 순서는 모델의 행동을 설명하는 것이지 인과관계를 반드시 보장한다고 할 수는 없음...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings(action='ignore')

import time
from glob import glob
from tqdm import tqdm

import tensorflow as tf
import tensorflow.keras as keras
from keras.models import Sequential, Model
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras import backend as K
# from keras.utils import plot_model

from keras.layers import Activation, Dense, LSTM, GRU, Bidirectional, AveragePooling1D, GlobalAveragePooling1D, Dropout, Flatten, BatchNormalization, TimeDistributed, Input, Reshape, RepeatVector, Concatenate, GlobalMaxPooling1D 
from keras.layers.convolutional import Conv1D, MaxPooling1D, AveragePooling1D


#GPU 자원이 부족
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
import os
os.chdir('/content/drive/MyDrive/신입기수 프로젝트/Dataset/')

# %%
# 결측치 처리한 수위4개+유량1개 데이터셋 가져오기
raw_data = pd.read_csv('Copy of 0827 광진행주유량수위x4.csv', encoding = 'cp949')

# 6912개 수위데이터 + 한강대교_수위 데이터셋 가져오기
newdata5 = pd.read_csv('newdata5.csv', encoding = 'cp949')

# 한강대교 수위 컬럼 추가
raw_data = pd.concat([raw_data, newdata5['한강대교_유량']], axis = 1)

# 6912개 수위 데이터 replace
raw_data.iloc[-6912:, [2, 3, 4, 5]] = newdata5.iloc[-6912:, [-4, -3, -2, -1]]

# %%
raw_data
# Out:
#         광진교_수위  행주대교_유량  청담대교_수위  잠수교_수위  한강대교_수위  행주대교_수위  한강대교_유량
# 0         1.20   540.18    310.7   300.2    290.0    275.3   729.80
# 1         1.20   540.18    314.7   300.2    290.0    275.3   731.48
# 2         1.20   540.18    313.7   301.2    290.0    275.3   726.42
# 3         1.20   552.17    311.7   301.2    290.0    276.3   726.42
# 4         1.20   564.29    311.7   301.2    291.0    277.3   707.17
# ...        ...      ...      ...     ...      ...      ...      ...
# 276331    1.12   974.40    288.0   295.0    299.0    306.0  -456.41
# 276332    1.12  1006.88    287.0   303.0    304.0    308.0  -717.30
# 276333    1.12  1039.90    299.0   307.0    309.0    310.0  -843.37
# 276334    1.12  1073.46    309.0   311.0    314.0    312.0 -1023.37
# 276335    1.12  1090.45    326.0   314.0    317.0    313.0 -1049.44
#
# [276336 rows x 7 columns]

# %%
x = raw_data[['청담대교_수위', '잠수교_수위',	'한강대교_수위',	'행주대교_유량', '광진교_수위', '한강대교_유량']]

# %%
x
# Out:
#         청담대교_수위  잠수교_수위  한강대교_수위  행주대교_유량  광진교_수위  한강대교_유량
# 0         310.7   300.2    290.0   540.18    1.20   729.80
# 1         314.7   300.2    290.0   540.18    1.20   731.48
# 2         313.7   301.2    290.0   540.18    1.20   726.42
# 3         311.7   301.2    290.0   552.17    1.20   726.42
# 4         311.7   301.2    291.0   564.29    1.20   707.17
# ...         ...     ...      ...      ...     ...      ...
# 276331    288.0   295.0    299.0   974.40    1.12  -456.41
# 276332    287.0   303.0    304.0  1006.88    1.12  -717.30
# 276333    299.0   307.0    309.0  1039.90    1.12  -843.37
# 276334    309.0   311.0    314.0  1073.46    1.12 -1023.37
# 276335    326.0   314.0    317.0  1090.45    1.12 -1049.44
#
# [276336 rows x 6 columns]

# %%
# 정규화
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

input_x_regular = x.copy()

for i in range(len(x.columns)):
    scaler = MinMaxScaler()                       #StandardScaler() , MinMaxScaler() , RobustScaler()
    a=np.array(input_x_regular.iloc[:,i])
    tmp_x = scaler.fit_transform(a.reshape(-1,1))
    input_x_regular.iloc[:,i] = tmp_x

# %% [markdown]
# # 원하는 칼럼명 입력하기

# %%
#ydata = raw_data[['현재수위','유입량','저수량','공용량','방류량','강화대교_조위','청담대교_유량','잠수교_유량','한강대교_유량']]
y = raw_data['한강대교_유량']

# %% [markdown]
# # 원하는 칼럼명 입력하기

# %%
input_regular = pd.concat([input_x_regular, y], axis = 1)
input_regular
# Out:
#          청담대교_수위    잠수교_수위   한강대교_수위   행주대교_유량    광진교_수위   한강대교_유량  한강대교_유량
# 0       0.049611  0.060000  0.051621  0.011070  0.056452  0.147596   729.80
# 1       0.053502  0.060000  0.051621  0.011070  0.056452  0.147654   731.48
# 2       0.052529  0.061111  0.051621  0.011070  0.056452  0.147478   726.42
# 3       0.050584  0.061111  0.051621  0.011475  0.056452  0.147478   726.42
# 4       0.050584  0.061111  0.052821  0.011883  0.056452  0.146810   707.17
# ...          ...       ...       ...       ...       ...       ...      ...
# 276331  0.027529  0.054222  0.062425  0.025719  0.045699  0.106425  -456.41
# 276332  0.026556  0.063111  0.068427  0.026815  0.045699  0.097370  -717.30
# 276333  0.038230  0.067556  0.074430  0.027929  0.045699  0.092994  -843.37
# 276334  0.047957  0.072000  0.080432  0.029061  0.045699  0.086747 -1023.37
# 276335  0.064494  0.075333  0.084034  0.029634  0.045699  0.085842 -1049.44
#
# [276336 rows x 7 columns]

# %% [markdown]
# # 원하는 칼럼명 입력하기

# %%
df_nanindex = pd.read_csv('/content/drive/MyDrive/신입기수 프로젝트/Dataset/rawdata.csv')

nanIndex = df_nanindex[df_nanindex['한강대교_유량'].isnull() == True].index

# %%
nanIndex
# Out:
# Int64Index([ 91352,  91353,  91354,  91355,  91356,  91357,  91358,  91359,
#              91360,  91361,
#             ...
#             262125, 262126, 262127, 262128, 262129, 262130, 262131, 262132,
#             262133, 262134],
#            dtype='int64', length=1279)

# %%
from tqdm import tqdm

xdata = []
ydata = []
xdata_idx = []
ydata_idx = [-1]
for i in range(len(input_regular.columns)-1):
    xdata_idx.append(i)

w =  6 #window size

idx = []
for i in range(12):
  idx.append(i*26496)

for i in tqdm(range(11)):
    if i != 10:
        tmp = input_regular[idx[i]:idx[i+1]]
    else:
        tmp = input_regular[idx[i]:]

    for j in range(len(tmp)-w):
        xdata.append(np.array(tmp.iloc[j:j + w, xdata_idx]).astype(float))

    for j in range(w,len(tmp)):
        ydata.append(np.array(tmp.iloc[j, ydata_idx]).astype(float))
# Out:
# 100%|██████████| 11/11 [03:07<00:00, 17.09s/it]

# %%
print(np.array(xdata).shape)
print(np.array(ydata).shape)
# Out:
# (276270, 6, 6)
# (276270, 1)

# %%
# 나중에 학습된 모델에 이거 넣어서 predict해서 결측치 채우기
x_real_predict = []
y_real_predict = []

for i in range(len(nanIndex)):
    k = nanIndex[-(i+1)]
    
    x_real_predict.insert(0,(xdata[k - w * (k // 26496 + 1)]))
    y_real_predict.insert(0,(ydata[k - w * (k // 26496 + 1)]))
    
    xdata.pop(k - w * (k // 26496 + 1))
    ydata.pop(k - w * (k // 26496 + 1))

# %%
print(np.array(x_real_predict).shape)
print(np.array(y_real_predict).shape)
# Out:
# (1279, 6, 6)
# (1279, 1)

# %%
print(np.array(xdata).shape)
print(np.array(ydata).shape)
# Out:
# (274991, 6, 6)
# (274991, 1)

# %%
pd.DataFrame(ydata).isnull().sum()
# Out:
# 0    0
# dtype: int64

# %%
xtrain = np.array(xdata[:-50000])
ytrain = np.array(ydata[:-50000])

xtest = np.array(xdata[-50000:])
ytest = np.array(ydata[-50000:])

# %%
print(xtrain.shape)
print(ytrain.shape)
print(xtest.shape)
print(ytest.shape)
# Out:
# (224991, 6, 6)
# (224991, 1)
# (50000, 6, 6)
# (50000, 1)

# %% [markdown]
# ## 모델 생성

# %%
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true))) 

if 'model_enc_dec_cnn' in locals(): 
    del model_enc_dec_cnn 
if 'history' in locals():
    del history

optimizer = tf.keras.optimizers.Adam(lr=0.01) #기본값 0.001

model_enc_dec_cnn = Sequential()
model_enc_dec_cnn.add(Conv1D(filters=64, kernel_size=2, padding = 'causal', activation='relu', input_shape=(w, xtrain.shape[2])))
#model_enc_dec_cnn.add(Conv1D(filters=64, kernel_size=2, padding = 'causal', activation='relu'))
#model_enc_dec_cnn.add(MaxPooling1D(pool_size=2))
model_enc_dec_cnn.add(Flatten())

model_enc_dec_cnn.add(RepeatVector(1))
model_enc_dec_cnn.add(LSTM(200, activation='relu', return_sequences=True))
model_enc_dec_cnn.add(LSTM(200, activation='relu', return_sequences=True))
# model_enc_dec_cnn.add(LSTM(200, activation='relu', return_sequences=True))
# model_enc_dec_cnn.add(LSTM(200, activation='relu', return_sequences=True))
# model_enc_dec_cnn.add(LSTM(200, activation='relu', return_sequences=True))
model_enc_dec_cnn.add(LSTM(200, activation='relu'))

model_enc_dec_cnn.add(Dense(100, activation='relu'))
model_enc_dec_cnn.add(Dense(1))

model_enc_dec_cnn.compile(loss=root_mean_squared_error, optimizer=optimizer, metrics =["accuracy"])

model_enc_dec_cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 6, 64)             832
#
#  flatten_1 (Flatten)         (None, 384)               0
#
#  repeat_vector_1 (RepeatVect  (None, 1, 384)           0
#  or)
#
#  lstm_3 (LSTM)               (None, 1, 200)            468000
#
#  lstm_4 (LSTM)               (None, 1, 200)            320800
#
#  lstm_5 (LSTM)               (None, 200)               320800
#
#  dense_2 (Dense)             (None, 100)               20100
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 1,130,633
# Trainable params: 1,130,633
# Non-trainable params: 0
# _________________________________________________________________

# %%
# plot_model(model=model_enc_dec_cnn, show_shapes=True)

# %%
epochs = 100
batch_size = xtrain.shape[0] // 1000
validation = 0.2

checkpoint_callback = ModelCheckpoint(filepath='best_model.h5', save_weights_only=False, monitor='val_loss',
                                         mode='min', save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', min_delta=0.005, patience=10, mode='min')
rlrop_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.5, mode='min', patience=3, min_lr=0.001)

# %%
## 학습

history = model_enc_dec_cnn.fit(xtrain, ytrain, verbose=1, epochs=epochs, batch_size=batch_size, validation_split=validation,callbacks=[early_stopping_callback, checkpoint_callback, rlrop_callback])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 45s 50ms/step - loss: 216.9634 - accuracy: 1.7779e-04 - val_loss: 101.2784 - val_accuracy: 2.2223e-05 - lr: 0.0100
# Epoch 2/100
# 804/804 [==============================] - 37s 46ms/step - loss: 104.3847 - accuracy: 2.6668e-04 - val_loss: 156.8668 - val_accuracy: 3.7779e-04 - lr: 0.0100
# Epoch 3/100
# 804/804 [==============================] - 37s 46ms/step - loss: 96.0028 - accuracy: 2.3334e-04 - val_loss: 69.9049 - val_accuracy: 2.4445e-04 - lr: 0.0100
# Epoch 4/100
# 804/804 [==============================] - 39s 48ms/step - loss: 82.4201 - accuracy: 2.5001e-04 - val_loss: 67.8669 - val_accuracy: 1.1111e-04 - lr: 0.0100
# Epoch 5/100
# 804/804 [==============================] - 37s 46ms/step - loss: 75.9231 - accuracy: 2.3890e-04 - val_loss: 65.9649 - val_accuracy: 4.0001e-04 - lr: 0.0100
# Epoch 6/100
# 804/804 [==============================] - 39s 48ms/step - loss: 71.8153 - accuracy: 2.4446e-04 - val_loss: 58.2323 - val_accuracy: 4.4445e-05 - lr: 0.0100
# Epoch 7/100
# 804/804 [==============================] - 37s 46ms/step - loss: 70.3861 - accuracy: 2.7779e-04 - val_loss: 96.4629 - val_accuracy: 2.2223e-05 - lr: 0.0100
# Epoch 8/100
# 804/804 [==============================] - 37s 46ms/step - loss: 72.2581 - accuracy: 2.6112e-04 - val_loss: 72.8296 - val_accuracy: 4.4445e-05 - lr: 0.0100
# Epoch 9/100
# 804/804 [==============================] - 38s 48ms/step - loss: 67.6307 - accuracy: 2.9446e-04 - val_loss: 60.7463 - val_accuracy: 6.6668e-05 - lr: 0.0100
# Epoch 10/100
# 804/804 [==============================] - 37s 46ms/step - loss: 56.2494 - accuracy: 3.1668e-04 - val_loss: 54.8764 - val_accuracy: 1.3334e-04 - lr: 0.0050
# Epoch 11/100
# 804/804 [==============================] - 37s 46ms/step - loss: 55.9992 - accuracy: 2.8890e-04 - val_loss: 52.0849 - val_accuracy: 2.2223e-04 - lr: 0.0050
# Epoch 12/100
# 804/804 [==============================] - 38s 48ms/step - loss: 53.8358 - accuracy: 2.9446e-04 - val_loss: 53.1913 - val_accuracy: 6.6668e-05 - lr: 0.0050
# Epoch 13/100
# 804/804 [==============================] - 37s 46ms/step - loss: 55.3213 - accuracy: 2.6112e-04 - val_loss: 56.3986 - val_accuracy: 8.8891e-05 - lr: 0.0050
# Epoch 14/100
# 804/804 [==============================] - 37s 46ms/step - loss: 54.1150 - accuracy: 2.9446e-04 - val_loss: 52.8216 - val_accuracy: 6.6668e-05 - lr: 0.0050
# Epoch 15/100
# 804/804 [==============================] - 39s 48ms/step - loss: 50.0269 - accuracy: 3.1668e-04 - val_loss: 55.0578 - val_accuracy: 2.2223e-04 - lr: 0.0025
# Epoch 16/100
# 804/804 [==============================] - 37s 46ms/step - loss: 50.6362 - accuracy: 3.2224e-04 - val_loss: 50.9494 - val_accuracy: 1.3334e-04 - lr: 0.0025
# Epoch 17/100
# 804/804 [==============================] - 37s 46ms/step - loss: 49.6345 - accuracy: 2.7223e-04 - val_loss: 48.9092 - val_accuracy: 1.1111e-04 - lr: 0.0025
# Epoch 18/100
# 804/804 [==============================] - 39s 49ms/step - loss: 49.6317 - accuracy: 3.0557e-04 - val_loss: 52.1356 - val_accuracy: 2.4445e-04 - lr: 0.0025
# Epoch 19/100
# 804/804 [==============================] - 37s 46ms/step - loss: 49.4106 - accuracy: 2.8890e-04 - val_loss: 50.9173 - val_accuracy: 1.7778e-04 - lr: 0.0025
# Epoch 20/100
# 804/804 [==============================] - 37s 46ms/step - loss: 49.5687 - accuracy: 3.2779e-04 - val_loss: 49.6773 - val_accuracy: 6.6668e-05 - lr: 0.0025
# Epoch 21/100
# 804/804 [==============================] - 39s 49ms/step - loss: 46.9777 - accuracy: 3.0001e-04 - val_loss: 51.3197 - val_accuracy: 8.8891e-05 - lr: 0.0012
# Epoch 22/100
# 804/804 [==============================] - 37s 47ms/step - loss: 47.0103 - accuracy: 3.1112e-04 - val_loss: 48.4816 - val_accuracy: 1.7778e-04 - lr: 0.0012
# Epoch 23/100
# 804/804 [==============================] - 37s 46ms/step - loss: 47.0859 - accuracy: 3.1668e-04 - val_loss: 49.7488 - val_accuracy: 1.1111e-04 - lr: 0.0012
# Epoch 24/100
# 804/804 [==============================] - 39s 48ms/step - loss: 47.0387 - accuracy: 3.1668e-04 - val_loss: 49.6493 - val_accuracy: 8.8891e-05 - lr: 0.0012
# Epoch 25/100
# 804/804 [==============================] - 37s 46ms/step - loss: 46.9498 - accuracy: 3.3335e-04 - val_loss: 50.9929 - val_accuracy: 8.8891e-05 - lr: 0.0012
# Epoch 26/100
# 804/804 [==============================] - 39s 48ms/step - loss: 46.3134 - accuracy: 3.0557e-04 - val_loss: 51.8658 - val_accuracy: 1.7778e-04 - lr: 0.0010
# Epoch 27/100
# 804/804 [==============================] - 37s 46ms/step - loss: 46.0774 - accuracy: 3.1112e-04 - val_loss: 48.7042 - val_accuracy: 1.1111e-04 - lr: 0.0010
# Epoch 28/100
# 804/804 [==============================] - 37s 46ms/step - loss: 46.0747 - accuracy: 3.0001e-04 - val_loss: 48.6569 - val_accuracy: 1.1111e-04 - lr: 0.0010
# Epoch 29/100
# 804/804 [==============================] - 39s 48ms/step - loss: 45.9535 - accuracy: 3.0557e-04 - val_loss: 50.1340 - val_accuracy: 1.1111e-04 - lr: 0.0010
# Epoch 30/100
# 804/804 [==============================] - 38s 48ms/step - loss: 45.7766 - accuracy: 3.0557e-04 - val_loss: 49.5571 - val_accuracy: 1.1111e-04 - lr: 0.0010
# Epoch 31/100
# 804/804 [==============================] - 37s 47ms/step - loss: 46.0918 - accuracy: 2.8335e-04 - val_loss: 50.6313 - val_accuracy: 1.1111e-04 - lr: 0.0010
# Epoch 32/100
# 804/804 [==============================] - 39s 49ms/step - loss: 45.7309 - accuracy: 3.3890e-04 - val_loss: 48.4262 - val_accuracy: 1.1111e-04 - lr: 0.0010
# Epoch 33/100
# 804/804 [==============================] - 37s 46ms/step - loss: 45.6967 - accuracy: 3.0001e-04 - val_loss: 50.1386 - val_accuracy: 6.6668e-05 - lr: 0.0010
# Epoch 34/100
# 804/804 [==============================] - 37s 47ms/step - loss: 45.7537 - accuracy: 3.4446e-04 - val_loss: 51.1731 - val_accuracy: 8.8891e-05 - lr: 0.0010
# Epoch 35/100
# 804/804 [==============================] - 39s 48ms/step - loss: 45.6980 - accuracy: 3.1668e-04 - val_loss: 50.6491 - val_accuracy: 1.1111e-04 - lr: 0.0010
# Epoch 36/100
# 804/804 [==============================] - 37s 46ms/step - loss: 45.6265 - accuracy: 3.0557e-04 - val_loss: 49.1711 - val_accuracy: 6.6668e-05 - lr: 0.0010
# Epoch 37/100
# 804/804 [==============================] - 39s 48ms/step - loss: 45.3368 - accuracy: 3.2779e-04 - val_loss: 48.5601 - val_accuracy: 1.1111e-04 - lr: 0.0010
# Epoch 38/100
# 804/804 [==============================] - 37s 46ms/step - loss: 45.4697 - accuracy: 3.0001e-04 - val_loss: 50.7590 - val_accuracy: 1.1111e-04 - lr: 0.0010
# Epoch 39/100
# 804/804 [==============================] - 37s 46ms/step - loss: 45.2818 - accuracy: 2.9446e-04 - val_loss: 50.5525 - val_accuracy: 1.1111e-04 - lr: 0.0010
# Epoch 40/100
# 804/804 [==============================] - 39s 48ms/step - loss: 45.2657 - accuracy: 3.1112e-04 - val_loss: 52.0688 - val_accuracy: 8.8891e-05 - lr: 0.0010
# Epoch 41/100
# 804/804 [==============================] - 37s 46ms/step - loss: 45.2039 - accuracy: 3.2224e-04 - val_loss: 49.9134 - val_accuracy: 8.8891e-05 - lr: 0.0010
# Epoch 42/100
# 804/804 [==============================] - 37s 46ms/step - loss: 45.3146 - accuracy: 3.5002e-04 - val_loss: 49.2298 - val_accuracy: 1.3334e-04 - lr: 0.0010

# %%
## 평가

keras_model_best = keras.models.load_model('best_model.h5', custom_objects={'root_mean_squared_error': root_mean_squared_error})

yhat = keras_model_best.predict(xtest, verbose=1)

yhat

keras_model_best.evaluate(xtest,ytest)
# Out:
# 1563/1563 [==============================] - 10s 6ms/step
# 1563/1563 [==============================] - 11s 6ms/step - loss: 45.9482 - accuracy: 1.6000e-04
# [45.948219299316406, 0.00015999999595806003]

# %%
## 학습 과정 시각화

fig, loss_ax = plt.subplots(1, 2)
fig.set_size_inches((15,5))

loss_ax[0].plot(history.history['loss'], 'b', label='train loss')
loss_ax[0].plot(history.history['val_loss'], 'r', label='val loss')

loss_ax[1].plot(history.history['accuracy'], 'y', label='train acc')
loss_ax[1].plot(history.history['val_accuracy'], 'g', label='val acc')

loss_ax[0].set_xlabel('epoch')
loss_ax[0].set_ylabel('loss')
loss_ax[1].set_xlabel('epoch')
loss_ax[1].set_ylabel('accuray')

loss_ax[0].legend(loc='upper right')
loss_ax[1].legend(loc='lower right')

plt.show()

# %%
## 결과 시각화

tl_predict = np.array(yhat)

#결과 시각화
plt.figure(figsize=(15,10))
plt.plot(ytest, marker = ",", label = "actual")
plt.plot(tl_predict, marker = ",", label="predict", alpha = 0.5)
plt.legend(prop={'size':10})  

plt.show()

# %%
## 점수 확인
print("RMSE : ",float(root_mean_squared_error(ytest, tl_predict)))
# Out:
# RMSE :  51.2393746429033

# %% [markdown]
# ## 파일 저장

# %%
x_real_predict = np.array(x_real_predict)
y_real_hat = keras_model_best.predict(x_real_predict, verbose = 1)
# Out:
# 40/40 [==============================] - 0s 6ms/step

# %%
for i in range(len(nanIndex)):
    raw_data.iloc[nanIndex[i]] = np.float64(y_real_hat[i])

# %%
raw_data.to_csv('/content/drive/MyDrive/신입기수 프로젝트/Dataset/newdata7_한강대교_유량_광진교_포함.csv', index = False, encoding = 'cp949')
